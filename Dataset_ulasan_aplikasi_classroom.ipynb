# %% [markdown]
# <a href="https://colab.research.google.com/github/AqielMubarok/Project-UAS-NLP/blob/main/Dataset_ulasan_aplikasi_classroom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install 'google-play-scraper'
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.7/dist-packages (1.0.2)

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.google.android.apps.classroom',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=1000, # defaults to 100
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.google.android.apps.classroom',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
result
# Out:
# [{'at': datetime.datetime(2021, 11, 8, 10, 14, 8),
#   'content': 'Suka kok sama apk ny, tapi kesel sama tgs" ny😔',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOE7IaVfDeRLiAkFj7-PXe1yTwUsn3WC2db4ozehXv3Ho4gwXbO5rsG9-RguoBSz8_RhcJDP6sdNtGmNEGo',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjMflfoAeK9yybrv_ft8tjlaqkxAijisxp-3CX-3g',
#   'userName': 'Angelina ClaraCantika'},
#  {'at': datetime.datetime(2021, 9, 28, 3, 4, 41),
#   'content': 'Apk ini bagus sekali saya bisa mengerjakan dan mengirim tugas saya di apk ini, saya kasih bintang lima.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOHjFTuJBqQ90rBDW6LFyZNns3BOza_YVLLoECRtIzMBtC1GCn7pxVmsLxhgFXFt8ZOH6wg8aCydYo3ffzY',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjbXcustkidA-w7DcU4T3fm6NAFLg2Y0pjEaex4rw',
#   'userName': 'Komang Novita'},
#  {'at': datetime.datetime(2021, 10, 27, 5, 10, 38),
#   'content': 'Menurut saya untuk keseluruhan sudah bagus tapi ada beberapa fitur yang tidak bekerja dengan semestinya dan masih banyak bug.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGeGdSMSqVPbf_b5IHCSvZORIrzL1DzLCCaiF_KpTgboxkFASFidJOuC36Dc3EWpq61oG79a980rnSrS0s',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi4hjk3vOazPAKmOaU0I_HbiWvgy7VFfcx-DZRaiQ',
#   'userName': '8C.32. Yuma Raissia Manggala'},
#  {'at': datetime.datetime(2021, 10, 6, 3, 39, 37),
#   'content': 'Awal nya sih baik baik saja,tapi lama kelamaan kok di saya gak ada notifikasi tugas yang masuk padahal setiap hari kelas saya selalu di kasih tugas.sampai Sampai saya ketinggalan ngumpulin tugas.tolong perbaiki lagi ya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHLTr-RSEuZkWYUTWIBhqM-2upykqizsfAb2HQ_D55vKOBMC_0O7eP2qpceAdFHiifrtQ_4rEzphi77kJk',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxYsO1u3pKuHLf0nFtZZf6A2jBcOt9RTKPCneWu=mo',
#   'userName': 'Unik Hidayah'},
#  {'at': datetime.datetime(2021, 9, 28, 1, 44, 40),
#   'content': "Saya udah masuk grup ipa saya, tapi kok gak keliatan di app, giliran di google chrome ada. Ada error' nya nih app",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.1',
#   'reviewId': 'gp:AOqpTOFsNkVslgMa-BiIfKu1-d5EdktltkT1uPcSIpO4QHJNTAVJsw_aTESB_E7M2Jg8JOUXpGIWck2GLvJoPK8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhwLfq2o61cB_PCMAx9lZpP6fQZdXl3YhhY_Ld_2A',
#   'userName': 'Putri Praz'},
#  {'at': datetime.datetime(2021, 10, 8, 5, 52, 34),
#   'content': 'Setelah di update classroom jadi jelek. Tidak ada notifikasi tugas dari guru. Tolong di perbaiki secepatnya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFopu62g-Ilpqmsw4X2K8Six0P_KnlA8OtN0XME92bQzyA0l3tkDVIpuVpwh2U8na50pM7IFa2XCRQkXb4',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj9u0BggTmNlbCdwVCLfe5eQj7lgAmwnCYX3TA7',
#   'userName': 'Amelyarihanン'},
#  {'at': datetime.datetime(2021, 9, 15, 11, 34, 34),
#   'content': 'Apk nya bagus banget tapi sayang masih ada bug,setiap hari selalu ada notif tugas tolong diperbaiki bug nya🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOE09qfJe2pfpYN2Atn9DWX5HIChFMXJORcbp0lMArIHr548-cgOTPHY-ootAw1_ktmidrDONUc8nZRjelw',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GimYPEcLk5XshHh-Dmnn-TvR1nxr64UDel7UGkJUQ',
#   'userName': 'muhammad ridho'},
#  {'at': datetime.datetime(2021, 10, 28, 23, 42, 39),
#   'content': 'Ngelag , bahkan sampai freeze. Setelah itu mengalami black screen.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOElOe6-HggeZlTYeTIQosN177ZLrLKb31CvNff4EfcB7TQSG4Pga7TJeUX7YMJ0xuZgn4VH7bRTiUoJc9M',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhLnYcnQqGvCBoFhvSvJWazakzNIQgZ7BpozxA_',
#   'userName': 'Kak Dyo'},
#  {'at': datetime.datetime(2021, 9, 9, 13, 5),
#   'content': 'sejak awal download selalu dapat notif tugas di pagi hari. Tolong dong di perbaiki bug ini. Sangat menggangu pagi saya.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.09',
#   'reviewId': 'gp:AOqpTOEAeWYo-aBnLGCa8aKjLnbjRjDaiD3l2BIzUJhSAH1Hg1PIPkmUaNb9cnPDyuAAfVirtwKSDN5d0D3gk1A',
#   'score': 2,
#   'thumbsUpCount': 7,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiYBR60-7ouUj_kaUNpZmXj097zzGhmnf3rNIXwmA',
#   'userName': 'Farid putra Pratama'},
#  {'at': datetime.datetime(2021, 9, 27, 7, 8, 22),
#   'content': 'YANG BENER NAPA WOY! NGIRIM TUGAS LOADINGNYA LAMA BATT ANJERRR SUMPAH KESEL AKUUU!!!!!!!!!!! PERBAIKI APK INI BUAT SEKOLAH INI, KALAU GA BUAT SEKOLAH MA GAPAPA',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOFL8g34Tvi3q78pZ2oanu72yKXvhoxRoZO59BWfl20P_CUviM-H7Uk-quDnL9_RrEcsnkwp8uODm4QO54M',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgtmLzEpLI59kwdidjKOarYPKsRRgEsXwtjiwINEA',
#   'userName': 'Hwang Dea'},
#  {'at': datetime.datetime(2021, 11, 8, 9, 57, 20),
#   'content': 'Ini kenapa pas update kelas nya hilang',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGeifjKqPtdDzcADL0H0ygKexnBL6eIfKpXlG_0sC8JPIhYu3aXQVkUnokq2aYRMu0iUPuTH0YHv5iGtV4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxGuB4yVe6Z_UaGTwO1Q7j9CjHv9PkEIl9Te4jl=mo',
#   'userName': 'Muhammad Rizky Rizky'},
#  {'at': datetime.datetime(2021, 9, 20, 8, 41, 30),
#   'content': 'Sangat berguna 👌 untuk nilai rapot ya walaupun tiap hari tugas dikirim eheh tapi dah tanggung jawab kita sebagai murid jadi janganlah dijadikan beban omke 🗿👍🏻',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOES7rugY9B6Q0wroQ302JWkQlR4PyUrbdMKxvOY6VyFe2NxMi5fuOQhvfs2EHjtD22PzpgPykgqbM7JmA4',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh5jNQnk0TJYrRw0MvMtrjoK6fzJO70ddAnaUshfw',
#   'userName': 'ADITYA PRATAMA SANWANI'},
#  {'at': datetime.datetime(2021, 9, 15, 2, 31, 12),
#   'content': 'G bisa buka video ..selalu ada tulisan periksa sinyal inet.pake wifi pke data seluler sama aja..pdhl hp aman g ada kendala',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOGyyqyUUTAgZSG1cNomb7QGy-MvClwdHkqqqFU7RaloxaOXZVE6YVTbb8CKQTFHURdWAqsC6VsC5BTZx1I',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg53ZBLJqyx5k9W3-5FOc5504Cb65NibmUY2ksifQ',
#   'userName': 'Muhammad Arif Rahmansyah'},
#  {'at': datetime.datetime(2021, 9, 20, 9, 19, 30),
#   'content': 'Tolong saat sedang mengupload file tambahan persentase pengiriman agar dapat diketahui berapa lama lagi file tersebut bisa di serahkan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGK9X98w2oJAHcADmX1p-pmbqEhbrtLWPKrwqFRMqzEexDNnxPo97REbdnIVhuGUxCfvB6BSIb_Ieeh4tQ',
#   'score': 4,
#   'thumbsUpCount': 18,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiNYsHpL1vYJTAXSWWXxsSHou-QIUz6EBek3JP2Cw',
#   'userName': 'Galvin Gundalin'},
#  {'at': datetime.datetime(2021, 9, 21, 0, 26, 55),
#   'content': 'Aku suka banget sama classroom karena gampang kalau nyari tugas yang belum di kerjakan Bintang 5 deh buat CLASSROOM💫💫💫💫💫',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.30.04',
#   'reviewId': 'gp:AOqpTOHCvywyioPa0bmu2bl1nbZBSWZSGOUMhA7hvzunt6AVGNW8vJb8V4JaqeRj5DcG4SCTqsLdOfwcZksNT3E',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhezM47XmLBqEfL4BP1aPJrul_6UO22Cc_F2ipw',
#   'userName': 'Almira Talita Sakhi'},
#  {'at': datetime.datetime(2021, 10, 2, 11, 20, 58),
#   'content': 'Ada bug baru y itu setiap saya bangun pasti ada notif sekolah dan itu menganggu banget sumpah ltolong diperbaiki bugnya :V',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFnCDUsneV-hTYqAeyOEJm6cw8MW1AuhWbOly9fPX9wu_ZQpe2l2jEG9cOMm1WASvA2vEkYSXHqz-GittQ',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgvIUS0a_r17r_y_rGh2PXtPjKw3V9tHmnPbmFACA',
#   'userName': 'ANUGRAH Putra'},
#  {'at': datetime.datetime(2021, 9, 27, 8, 54, 22),
#   'content': 'Banyak bug, lagi rebahan tiba-tiba ada notif tugas ini sangat mengganggu tolong developer segera di perbaiki',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOFA95-Y_dZmdIDY589D1FvE5RXr1lwqXlt7Ux5N1jkXWestM43mOwMW0TflM0I6a5FVB4mMhmFUvTpzk38',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiB5YIhH0ACpgEyoR28q__wLQsp612PblUgntR4aw',
#   'userName': 'Rangga PW'},
#  {'at': datetime.datetime(2021, 11, 22, 4, 56, 29),
#   'content': 'Kok tenggat nya sering terlambat si?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGy7b1N9Kn_w5VBbkniR0LqWP-RBvH1O0-5Kl9MyKNrUDgugMceS5nmF9RzH151HEfjEyOPpFQKy5_gTEs',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh3iWkS79iBBtH-R7Wi675wj8wU0dp5LM3sKo9BbA',
#   'userName': 'Hasegawa Ony'},
#  {'at': datetime.datetime(2021, 10, 13, 6, 53, 53),
#   'content': 'Aplikasi google classroom saya memiliki bug Yang sangat meresahkan dan merepotkan yaitu ada pesan terus menerus dan spam tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOE8UtVlYpwgCxWhQCYmMmVYcTaTOYjttB_FsGW8ETjRd8CK_mLXibQzgOejPd1nmRmjp59cfUTpgBiD0JE',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg62b6LRGWfoywczVqo-6FjjKJCoUuyGp7LQXs5NA',
#   'userName': 'ANANDA Nikolas Putra'},
#  {'at': datetime.datetime(2021, 10, 6, 5, 4, 44),
#   'content': 'Kekurangannya saat ingin mengirimkan file , sangat lambat , dimohon pihak Google untuk memperbaiki nya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOF4PIte4ynf2PTewZx_aLlDdzIZ2dT1mfrNB_X5Sn96PYDQH1AjdPSi-wOLZCdWt-SKie2op6MJBrAfzes',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhMUNjPVgPKNDIo6flkgll6rQFc_kKHWKmgoXNYWQ',
#   'userName': 'Angga Ardiansyah'},
#  {'at': datetime.datetime(2021, 10, 2, 5, 56, 43),
#   'content': 'Aplikasinya bagus banget tapi ada satu bug bug nya itu ada notif pas aku pencet kok muncul tugas banyak yah tolong diperbaiki🙏🏻🗿',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOE0UTsmN9FrQAEUjOMY8GnjY8LQ2U-jLRKoEBcJBL94OHK89HH7ryBCrWvKLz3VnhFwyT0k1TPSOf4Msnk',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi1jn7Mn2ITBSeIffzouLiWkTa9Qfh3Jvleo7Il',
#   'userName': 'Rifki Arya Saputra'},
#  {'at': datetime.datetime(2021, 10, 28, 2, 59, 41),
#   'content': 'Tolong dihapus aplikasinya, karena aplikasi ini bisa merusak generasi bangsa!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOHvGXsWAQX56i9BcFJ_2jPmjjG3HzlEVviNUcdwARdR6Z63keRvCV2_UNs9juJDYuzQbYoaW0DvvSAuWTM',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj7hF2GmwaEIS0-9dHtr8ec5D0dBKBBo5JGbCxMhg',
#   'userName': 'Hawwin Farrel'},
#  {'at': datetime.datetime(2021, 9, 23, 3, 8, 18),
#   'content': 'Apk nya bagus!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!tapi bohonk',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOEhmQ14QnLeicOrNp9q81XteUqZJVYeyKtz7FPDCgfkht9fPbQIWth5-UF958BKvdojWlsZbt5nsvIHOiA',
#   'score': 1,
#   'thumbsUpCount': 16,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxlpCa-rfozPEl3ZGnWfCafZkShpPRvVxoER-6y=mo',
#   'userName': 'Naufal Ahmad'},
#  {'at': datetime.datetime(2021, 9, 25, 9, 58, 16),
#   'content': 'Tolong bug nya perbaiki.kenapa setiap saya bangun tidur bug notifikasi tugas nya langsung di Spam gak jelas!!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOE018ZH5f3UpSi0LzJLUrpheEc44czVhz2x7QJFTSmS3zccltZKY1Nbo6ry9QZuoT5P4CiKagHBxfGKk4M',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhtRBBMGejKRBJVw0C8o1QONpSftLqHOclJ0xhv-g',
#   'userName': 'Ardhika raffy Muhammad'},
#  {'at': datetime.datetime(2021, 9, 8, 2, 28, 21),
#   'content': 'Ini aplikasi bagus tapi tolong diperbaiki saya kok mau buka file di suruh doanload youtube terus padahal saya udah ada youtubenya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.30.03',
#   'reviewId': 'gp:AOqpTOF9Q-ygT5AYdUG55QIXsOn9I73B9pquuGOIcYLouCaNWB9h8sDP5QAFuZgsCPj6g2J08x0n-CRyTILAQUc',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GigPNRJsBzTA54LlYgLzjpmtEnk_xGaY4s62ex3',
#   'userName': 'Wira Azmi'},
#  {'at': datetime.datetime(2021, 10, 15, 1, 46, 38),
#   'content': 'Aplikasi nya bagus tapi kurang satu fitur, fitur search buat nyari pelajaran lama kalo udah ada bari bintang 5',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGJhvd3Wx4CA9jRx0IzrCBUn5H6wfE3pkMsQopQRcEEkj7CXxBa_CTGmPRZY2iuowhNm-o_jZcoRShG9O8',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwILUC_TqbWGMXmYDQwclU30yoSEfiF3uPQsgTP=mo',
#   'userName': 'Rayan Direz'},
#  {'at': datetime.datetime(2021, 11, 2, 11, 3),
#   'content': 'Tolong dong tugas nya jangan banyak banyak fakk >:(',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.4',
#   'reviewId': 'gp:AOqpTOH2KzFE3vzlAAiKyMGtCjsLtrrwcs-9hwItztn6hluONbsGyOU-SeqI3DQJN4QEETzqHDQ7nv3V2N-AGjk',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiWSz1YOQgJxlC-Fx-jYb9x0u89-pf88CFlx9u-',
#   'userName': 'Mhd Raa'},
#  {'at': datetime.datetime(2021, 11, 2, 15, 47, 24),
#   'content': 'Setelah diperbarui kok malah notifnya hilang?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOFaj_SAUkQaqy_yQtJPbjNA2VmTl4ohTvQsR1uLn7kqxmSy01a2D3wXewAmm7yjDDwqchMzxv-RBYHWtH0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhRN6_dksMmQhMtrHBbb-gNykQIlC79FfwdAbGUGg',
#   'userName': 'Rifani'},
#  {'at': datetime.datetime(2021, 10, 29, 0, 58, 42),
#   'content': 'Gak bisa ngirim tugas nih gimana?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHJIUZYjB3SiSlB7Q5gGtrrTybQbIwkK_9gCbHOshHcAPVkgQs2UsnUKntQJDh041QUGLLe_fAoKw9DXYQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhgdGfn0TqoCSamFKYmtU68K8UrCg6_yQm385QCXg',
#   'userName': 'M.Rasya Firmansyah'},
#  {'at': datetime.datetime(2021, 9, 9, 6, 38, 56),
#   'content': 'kenapa saya gabisa buka link di gcr ya , saya jdi suka telat kalo ga pernah bisa buka link di gcr. tolong di benerin lg.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.02',
#   'reviewId': 'gp:AOqpTOF-FzUUn3PibwDJe7mZT55LiT3v1z45jPqn5KojyKNQ2-R5G92iKg0wzoQnlIgIqNvBVD2Cyeb2kP8VQl4',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi7Qv9plW1ur31-cw9OCucGEKnKFbLAkcO3qD-5',
#   'userName': 'Abelli Vinolin'},
#  {'at': datetime.datetime(2021, 9, 10, 7, 8, 43),
#   'content': 'Tolong diperbaiki lagi..karena kelas saya sering hilang saat kode dimasukkan lali tidak bisa,itu mengganggu tugas saya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGot7wx37Or4m03wN15o0apRm7-aDZRMBGaDSx_XgRXUGDOnYlZLjW1hFjevTCTCvSZWoKLyhVVmgSXdTY',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi8BZVJvnLLi5rj67yAvGDIIxHTMU1gUNuNcpCn',
#   'userName': 'Tantri 22mei'},
#  {'at': datetime.datetime(2021, 10, 6, 5, 8, 36),
#   'content': 'Bagus aplikasinya. Tapi Kalau bisa si ketika ngirim tugas atau upload tugas. Ada dong notifikasi ketika tugas sedang dikirim jadi biar tau aja tugas nya bisa terkirim atau enggak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFhTMowVnQVc5RIzQLNIqkr2OIIhBEocQQdGah4cQL5zlh1Gwm6eRe7r01oEwYX59udqzTLb6IVSvmd9cg',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhLs6AGw1Hxm535u7aRcTr4k_zZuZbj7v4TeC9ncg',
#   'userName': '32. Fadilah'},
#  {'at': datetime.datetime(2021, 10, 6, 4, 29, 40),
#   'content': 'perbaiki notifikasi , kenapa notifikasi nya tidak muncul jadi kebanyakan murid murid telat absen padahal notif aplikasi nya gak muncul',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOEqZKXnqA2ScLqND7TaagGtfitX3y4dYMdRy6n7f6EAuKwa_kZzv9eziRbef6vUrCSFybRDqEDjsSj1mxA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiP2rPiCVIEEUqbkiLtL9MxiXygF3JLDGykDUD8zQ',
#   'userName': 'Dikaaa Firmansyah'},
#  {'at': datetime.datetime(2021, 9, 5, 19, 13, 42),
#   'content': 'knp akhir akhir ini kalok ada guru ngirim tugas dari yt, pdf, link gt suruh download apknya dulu, padahal udh ada apknya tp srh tetep download mohon di perbaiki itu mengganggu bngt',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.03',
#   'reviewId': 'gp:AOqpTOEhuO6AoVPYC7gE4hF38SLUaoLezTzox4vKOU_qCJpRPyazaQ-4Ju50eWje02OfQQzjNTOKVQlw7QatkjY',
#   'score': 2,
#   'thumbsUpCount': 24,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgStL7EkD3lbFpsDUJ3DeWvLSvNB_jFtqoueiCAGA',
#   'userName': 'Cahya Aulia'},
#  {'at': datetime.datetime(2021, 11, 2, 2, 49, 39),
#   'content': 'Aku suka sama Google kelas ini kocak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.4',
#   'reviewId': 'gp:AOqpTOFVZjYCEtdZf0xSSSdz_cFJ5ysTWB1E7HRHlq6sfpz9ugA1hPYF7VL9rIjVb93hUWsiK1Oiibfqpa_1NeA',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJy4V0TSBJJ4WHSsV9Ex3cqUNnEZF49TbZsW28rl=mo',
#   'userName': 'Erny Tuto'},
#  {'at': datetime.datetime(2021, 10, 13, 6, 37, 49),
#   'content': 'Saat mengirim tugas,file tidak bisa dibuka dan malah berbentuk drive,cepat diperbaiki ini menyusahkan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFlevvd9aUzd1UZZcQMAv8rAWAu_gBN-ckmsmtbgQhBsghtj3TfegrKQfFWjnCktPuWQvx_h_1ancxW56I',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzddAttuSA2Lj0ImGy8uDhk3tvqv-Fx9yYMu9sT=mo',
#   'userName': '26_Ni Luh Md Ayu Sri Wahyuni_X MIPA 2'},
#  {'at': datetime.datetime(2021, 11, 5, 1, 8, 41),
#   'content': 'Spam tugas terusss ampe stressss!!! Gurunya mah santuy aja nyepamin tugass',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.4',
#   'reviewId': 'gp:AOqpTOFEYcukZawipHbYKmtyESnit4G2BtS-DV1geGhvV62y6WRCZLp4Wm3VvItxnH5U9npOlxTVrlPiGdWwGC4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgsMB0_XxIVfYpiJRexUkOijhpCCYsZpugu5aE8',
#   'userName': 'Muhammad Havis fahrezi'},
#  {'at': datetime.datetime(2021, 11, 5, 12, 38, 6),
#   'content': 'Sekarang ngga ada notifnya jadi kalo ada tugas ngga tau !!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOG2lylHt60b8txtCu0AVpZsjSEwrNwy-Q-Pvew0UuzKc2j34j_8GueanjD-SaKAWXN_GTziAYypO9g1OGM',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjrsW60GeKiTm5CB7yb72LjZRXBI4_vdYYFONX4',
#   'userName': 'Asni Afitriana'},
#  {'at': datetime.datetime(2021, 9, 27, 13, 38, 34),
#   'content': 'Gak bisa absen tugas gak bisa di kurim..... Hampir di alpa plus dapat omelan dari guru.... (T_T)',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFf8_y7HIHuI19r4-Te7Fo_W8zoK8ApjkefjCXm5rEWyXX0kS-dfGWai6v4FyJxBoWYdrnAc2POrN9cU7w',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhVgevquIRwEyw4QZLcpKE2YS5VrCY_NtXahpWx',
#   'userName': 'Muhammad Rasyid official'},
#  {'at': datetime.datetime(2021, 10, 4, 1, 45, 5),
#   'content': 'Gimana sih sinyal bagus buat ngirim masih Leles perbaiki lagi!!!!! Kalo ga Corona gasudi donlod apk burii!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOHO5qMQX6SIbHvBN5mdyQvbyR3wVIDg8NUErWipIXA7N8MAVBnF7SHdaKnzPEyekas8c7tkY6PC7NeH6EQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgR4bfw5R0C3hP2sDggwbc_v--wwe5TdDjgrA3N',
#   'userName': 'RAFFI CHANNEL'},
#  {'at': datetime.datetime(2021, 9, 27, 13, 56, 51),
#   'content': 'Tolong diperbaiki!! Banyak notif keluar mullu. Dhal udh dikerjakan dri kmren2. tetep ae tulisannya belum dikerjakan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOHGi-n4UBB0hYdlF-B0ecTb6b9vTs5nYFAywtjhZTjdib9sFBhi7L-s4NzEfEkadOVkFzvRHOgir6LZTTU',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxKp12wUxcUy8MO4MATbY5WivTUR8Lwz2weEpOL=mo',
#   'userName': 'Yulie Rahmawati'},
#  {'at': datetime.datetime(2021, 11, 12, 4, 12, 33),
#   'content': 'Semenjak ada gcr, tugas makin banyak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOEY4lRYcUsKa9Afh3Dgy-V-QSgKGXvUV9v06lFIPI82ehvGQrJSamU7oX_dZxqW11NEziG_XnRZhYUnd7A',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjFTRri94oFlogBOcSMmIivN6QBjCja32etiYSv',
#   'userName': 'gojo satoru011'},
#  {'at': datetime.datetime(2021, 9, 11, 13, 58, 25),
#   'content': 'Bagus bangeett! Tapi ada banyak bug masa tiba" ada notif terus gw disuruh ngerjain tugas tolong fix!🙏 Karena sangat menggangu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFCjJdLe8Bi_8-14Cen5X_N0JSDwPFCGA0YVJXBm-SDvuHM1XADezN6oebdMq-IlauHjAoxN8TNWTWmCig',
#   'score': 1,
#   'thumbsUpCount': 22,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhJqgtQJTQTipDtxBpq3fWvUgNtvJVX1dW0yZ2-1g',
#   'userName': 'Kenji Satrio adi'},
#  {'at': datetime.datetime(2021, 10, 30, 16, 56, 51),
#   'content': 'Ada apa dengan Google Classroom??? Saya ngirim tugas kok gabisa??? Persetan!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.45.09',
#   'reviewId': 'gp:AOqpTOFrIO0FN4hT8T_sHZb0YfMMRZQkAJIVkvUnxfqFuy7bCflreQIliiIjpEIfdrOBvfPNYOmxJ9fpQ-KaZvw',
#   'score': 1,
#   'thumbsUpCount': 288,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi4s25bdZ_GYKleJnN6A9sXEPzxygnkNjlPEL8JMA',
#   'userName': 'Shofi Harto'},
#  {'at': datetime.datetime(2021, 9, 16, 7, 10, 6),
#   'content': 'Tolong bug nya cepat di atasi soalnya banyak notifikasi tugas yang banyak sekali . Tolong di fix bug nya 🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOHBhjMpbV4ejlZw1LQt58fCSldXXfizNlMogQssdw04TWy_zouKZpzZtmrkZXDKe4jZSUUTQNfLXlcsuCI',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg1AgTY4UH6-k49E0Jce0-mUqpmkrjhLfgb-ksu',
#   'userName': 'Desta rayhan .A.'},
#  {'at': datetime.datetime(2021, 9, 22, 13, 44, 43),
#   'content': 'Aplikasi sampah tugas saya numpuk mulu amnjing setiap pagi saya di suguhin tugas yang tak kunjung selesai seperti beban hidup',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGERA_fmp3NIEmGL2FuRr9vXQ063FTAp-zfCVivuCQlOr7p5H5cmdSQPetQH931mPZtHiBkU_lYIW_2XDc',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhejfLMwaweLm5uTQtHZvOiLGOhsa946MHN9tziDw',
#   'userName': 'damar raiputra hade'},
#  {'at': datetime.datetime(2021, 9, 15, 2, 25, 12),
#   'content': 'Makasih classroom, sekarang link yang tertaut dalam classroom baik youtube ataupun google form sudah dapat terbuka.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOGSgCnhPUgQVZwLtt8LZK8gjdjcVGRzvKOoUYJM37vCm7T5jOLyTHJTjNv1mtirY4km0gK_jFmcTXGRFTI',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghu_SAHTOEn8OLosvkXW_hnJyoeMtJlzDicaevYAA',
#   'userName': 'Larasati Ramadiyani'},
#  {'at': datetime.datetime(2021, 9, 7, 0, 3, 32),
#   'content': 'Tolong diberi notifikasi Jadi tdk perlu direfresh biar saya tau jika ada notifikasi yg masuk dan tidak tertinggal',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.03',
#   'reviewId': 'gp:AOqpTOHm8ysNDU8m36ffpkUEmrRFCsbmwKpZCE--AG-MoBFNTDiSIl06hS47O-8qHyocOjiTvM-tyV-TeaqcQ2c',
#   'score': 3,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjAMxzQjUpUlpLaYFN_WzgG-hruTrxVtUSC5cqMJQ',
#   'userName': 'Justin Alvaro'},
#  {'at': datetime.datetime(2021, 9, 22, 20, 48, 2),
#   'content': 'Awalnya bagus bgt,tapi kenapa pas mau pake buat absen ada "kelas tidak ditemukan" Plis bantuin, aku mau absen ini',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOHirOQgbS_pkxsDfX_w0KZ_F3vUooAyD_Ran0_jamVuWzUPYmzY1T6V-djh2SlKbgQWamTOpY1MhRG9Tns',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyNTKgPGOVWMCc4H7hAVN6XWTjiAGX-aVyz58Nc=mo',
#   'userName': 'nadinda ayu'},
#  {'at': datetime.datetime(2021, 10, 19, 0, 59, 53),
#   'content': 'Ini app banyak bug nya kenapa pas mau ngirim gk bisa eror tidak ad koneksi padahal pake wifi eror mulu ini app gk jelas tolong lah direspons sama google nya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGh3jgqC4b3ArbJx9LrcZIlihQHNLimCkROTM5mepZuG8XbNX79fG6x5QDa9Idv1JXvA1xZEXK_LYhgks0',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhkpTvkXR5rPibel06TQCjWYY5u-K-w8AwKDGJm',
#   'userName': 'Lathif Assidiqi'},
#  {'at': datetime.datetime(2021, 11, 22, 2, 20, 35),
#   'content': 'Bisa di perbaiki guru saya spam tugas🤕',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOE_2Q0M5wsIt3-fvWesYV6WboC9XdP5JCABjvjLsZzW2mlbCqgDRyCny8HJFHfO-2IutMLaYyjh8ivPLis',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjyo5ugFx-lFK8wqXzFnYg-d0awQ3u-aoulk-lZ',
#   'userName': 'rafael devonch'},
#  {'at': datetime.datetime(2021, 10, 1, 0, 48, 16),
#   'content': 'Bagus banget aplikasi nya !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOGLaBUHs07itQCkCioYlWAQqfVmxIGjQBidIUJttH2lN5P2EpWr6zjIwUCSj_ep8K8rOUA1GM6bm7kVmb4',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjYJg5glLbNTeUoBDrkIuy92V6JmoDdaBEhDOWU4w',
#   'userName': 'Muhammad Syahril Ramadhan'},
#  {'at': datetime.datetime(2021, 10, 12, 12, 2, 42),
#   'content': 'GW KIRIM TUGAS VIDEO KOK GA BISA YA?? PADAHAL DURASI DAN SIZE NYA MASIH NORMAL, GARA² GABISA DIKIRM GW JADI DIMARAHIN GURU MAPELNYA DI KELAS.. UNTUNG GW KASIH BUKTINYA KLO UDH GW KERJAIN DAN MASALAH SELESAI DENGAN DAMAI..',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEpAoCVbmsaOYwDI4sdZxg40rsMMP3PJQ4vf-gENU9mtFnz8HUaS99YYQcqxRLmnRMn6iX9T8m6vjMYp9Y',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiyP6HViqdt19y3plKkJLu859nQYWLqySv9trcV5Kw',
#   'userName': 'Febryan Dani'},
#  {'at': datetime.datetime(2021, 10, 26, 3, 0, 26),
#   'content': 'Aplikasinya membantu banget bagi yang suka yang belajar, pokoknya bagus banget',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEokRXKVWChHUMuk_ejaYt_z64oWOhe-UgXjV2h77AhGS1doCgfGj5q0m9mS19zpf8EC5jri6gqZYoGAgg',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw70sdUPb3EuUzDAcZKENRuYVx-DCiw-OaDh6N7=mo',
#   'userName': 'Andhira Khanza'},
#  {'at': datetime.datetime(2021, 10, 15, 4, 15, 15),
#   'content': 'Knp gcr skrng makin memburuk,seharusnya bisa lebih mempermudahkan dimasa pandemic ini. Tolong diperbaiki lagi',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHyuWMyPPtz9xmIEtIc-SfoFsSUxqSotgiCXZSWmfOM-W5H-FfTQS1u8mb3vqPftS4HWdM6i-d1xrlRThE',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiAo8kLGY5gJ2zDgSUBKtuDMHXXZrZwFKsUO2qA',
#   'userName': 'Nadya Nur Ilham'},
#  {'at': datetime.datetime(2021, 11, 11, 18, 21, 14),
#   'content': 'ntah knpa makin update malah bug ada notif tugas trus perlu perbaikan thanks',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGoR4f8OW42zhUZWhyroebn_0gMMjCdPc98taWOCaViLiM4-ZX65dAhXakrLwSh8qZ_8esJ7_AQwVh2CHU',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiJTTYkqOk8UZRKiiAecTMYzq3E_DKE29LJFvD1',
#   'userName': 'Didik Gunawan31'},
#  {'at': datetime.datetime(2021, 10, 15, 4, 59, 46),
#   'content': 'Saya gk bisa liat vidio saya, padahal baru dikirim dan setiap saya kirim tugas pasti ada yg gk ke kirim',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHSeqG24FCWAAs6N0JipSYUk2zsfUQJ836Y0NHnyPjjqAdp49GpjRBp_7RzhjBhsA-muVYR2uBj1XGz8R0',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhpwNXlGX5Jyc8tKYp012VNv_W6S8y5K3S68UHu',
#   'userName': '15. Fiora 6B'},
#  {'at': datetime.datetime(2021, 9, 20, 0, 14, 30),
#   'content': 'Saya susah memberikan tugas nya, loading terus dan nggak mau terlampir lampir, padahal sinyal nya bagus',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOG8ABKLwWn83g2mkq4ni9CBEBhsBxFsQPjXHd11MMHBmOuHZB3ykBnXhnVJOUFQqe5zkr1t9M1hybQXug8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhAO4QFf3_LC44pmDztLyDObBhO7Z3z_RVE2dyexA',
#   'userName': 'daniswara Paramapta'},
#  {'at': datetime.datetime(2021, 11, 8, 4, 8, 46),
#   'content': 'Bgs,cuma knp kdng" g bs ngirim tugas? 🤔',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHb6lV3Lvzo3K4Zs_rUQxBBlpIaLSlFd14soHXcxmhK0CVkL8tLGKUAVlyIY-jwl8tjAXR6R1KJuI0PWig',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjRAqION4FpcFffxJtzb70QdZiv_Ef2_rAAMqhdJg',
#   'userName': 'Dzakiyyah Nur Hibatullah'},
#  {'at': datetime.datetime(2021, 9, 30, 12, 4, 3),
#   'content': 'Bagus, aplikasi yang berguna untuk alternatif mengirim tugas, walaupun males ngisinya-_-',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOET_uxXgt5FCIPB6D32ehx33CBsym68c46tH8I0qc3tRZXzTh2IlYPrk_bBIEx3g3dzAE0UNWmgK15qg80',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwdEpTDTEq98Ei7hoKJBf-k1sxDxn7Gryt2KP45=mo',
#   'userName': 'Arifky Nurhidayat'},
#  {'at': datetime.datetime(2021, 9, 26, 12, 10, 5),
#   'content': 'Sangat mudah dan simpel untuk menilai dan mengirim tugas,, terimakasihz,,,,,,**,',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOHC82XUy5pLCy8sXyNXzc0AqqDHLJA07ttqahnYv2nUt_BzdpC8iRukO99dRAL4I4bXBrDYyMAOFIwJiYw',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgkDs0Nl7MS5hongboq6AUDnXoCoZfa9NXyJQxH',
#   'userName': 'Serlyana Sholekah Saputri XI Otkp'},
#  {'at': datetime.datetime(2021, 11, 17, 23, 22, 30),
#   'content': 'Dah lah sukurin aja apa adanya jangan ngebacot mulu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHz_UvZWbjrEKhtfVdrWTLIsk0B65D9XnKCZ2FTyg5IklGShEYPx9U9WREI8hgUR5TRjbv3GhAVF5lbupQ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhUeGMzRdgiQn_VT6VtGUJwZ1vHt9cxurXPVGJK',
#   'userName': 'Andy Rachman'},
#  {'at': datetime.datetime(2021, 11, 9, 14, 57, 7),
#   'content': 'Tidak dapat melampirkan file drive',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOF5uEjVqE9QADaknMG1YEr8cfUU25w80_KBb4BmhnPyUtoa7K2J3wcKOYae4B7BxPL0Ubi0W2FRZHZBhHw',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi_iAS5haEKqdtZ6Ivti3MEhOHRJCfIV-kUJW3PKg',
#   'userName': 'XI - H - 30 - Wibisana Andika'},
#  {'at': datetime.datetime(2021, 10, 31, 13, 27, 41),
#   'content': 'aplikasi ini sangat bagusssssssss banget bisa untuk belajar,mengajar, dan mengirim tugas, saya kasih bintang 5😊😊😊😊😊😊😊😊😊😊😊😊',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOENDkvEfHtJdHtAWI5fwuU5acepWeXxrBL66r5Hn6FMqWjXENxI9Uuyov_fsBH65OCiuId9pcpTgn3Uw_4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzIQFQikVMhSrtigi02r-36Rnck0DjNs8mmgID5=mo',
#   'userName': 'Nurul Awak'},
#  {'at': datetime.datetime(2021, 9, 5, 15, 27, 3),
#   'content': 'Aplikasinya bagus tetapi kenapa setelah di update ko setiap kali mau absen di suruh download chrome sedangkan chrome sudah terinstall di android.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.03',
#   'reviewId': 'gp:AOqpTOEGdKJLNsgROM1rcCDQaYSe2LnLUh43ILM6xgiVyzVD7fr2NrhVt7ThCVpq-Wb9G1lkZRYx2wbkzas4gVI',
#   'score': 1,
#   'thumbsUpCount': 101,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiH2XmuiaPBxgobZcXUQ0hmH6PwL21xL1VdxHxyyA',
#   'userName': 'Yapan Aplugi'},
#  {'at': datetime.datetime(2021, 9, 27, 7, 39, 8),
#   'content': 'Buat mengarsipkan dan mengembalikan arsip jadi ribet, dan file tugas yg dikirimkan hilang tidak bisa dibuka',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFXV3p_daiBrxWvDNU4sny0niuIvyw0AMixFNxPOmS96y_Bt2KO1rv2LCXUAWxS_bePEivBbrjzrVjPOdg',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgzA3zWOFw7Ma9_KGDjmiJYGl8CQEl9IXd7qectVg',
#   'userName': 'Muhammad Rizqi Abroori XI mipa 7'},
#  {'at': datetime.datetime(2021, 10, 23, 1, 45, 13),
#   'content': 'Aplikasi aneg, bug nya kebanyakan. Tiap pagi hp saya bunyi terus, saya kasih rate 1',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHhb8HicfzBDeRaQp9FW62UQO1LtGv9ia4td-wwiyT7LTi4NNluCNiyHJBeOcz4KMy5WXioWRKGGBesQEI',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhPqEeZnwuytHCOp2mmPfHMMnQ4b_4_2gmE4aXxLQ',
#   'userName': 'Rehan Ramadan'},
#  {'at': datetime.datetime(2021, 9, 21, 0, 55, 54),
#   'content': 'Untung pihak classroom tolong ya di perbaiki saya mau kumpulin di classroom ga bisa saya kira wifi saya ngelag pas saya uji nonton yt baik² aja tolong di perbaki ya tambahan tugas nya terima kasih 🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOE6YSuZyW8pnJbxJGu_pFITwPLr5KopgDDRPVKnDl-g_Upne03Lv7m9U34f8ZHetrvRAlm8gJ2HePw7fRc',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GifzubEg4BGw2f7_1vxSCrWb8JZT32suqqCTXAAOQ',
#   'userName': 'Taufik Ahmad Darmawan'},
#  {'at': datetime.datetime(2021, 9, 19, 6, 9, 22),
#   'content': 'Apk ini bagus banget,Kita bisa share tugas dan bisa hadir melalui ini,POKOK NYA APK NYA THE BEST BANGET LAH☺️',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFBHpsNf6HDfGL18EtaEgnlvsYUqoWnI6AqHuTPmDJxcIwxhJcD8csc11CzoxBg_lDfLHEk75c2bKHTnVU',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwL3a4TS6W_4t54OseeoOmyEeex6ztu9S1vRdAb=mo',
#   'userName': 'Anelsa Anelsa'},
#  {'at': datetime.datetime(2021, 9, 25, 16, 10, 17),
#   'content': 'Membantu Pelajar Belajar Daring / Dari Rumah Terimakasih Telat Membuat Classroom Dan Membantu Pelajar Belajar Online Sekian Terima Kasih..',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOGX_0z-N6EXM6SOdQcs6as6XqbShBfePGpYqTKk_EMz71PkZLq8zIBRA0tKptkN05R6aB9QJSVFeVr6eB0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxV1ki67xETs6yLIY6vFoNmY3e0xQe3buEXdAAn=mo',
#   'userName': 'Aditya Okta Farabi'},
#  {'at': datetime.datetime(2021, 10, 6, 12, 2, 30),
#   'content': 'Ini kenapa ya guru sudah mengirim tugas jam 09.00 pagi tapi keluar jam 4 sore batas waktu yang di berikan sampai jam 1 siang jadi nilai berkurang',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGieBF6TxU4NgCNfjN3uupCe2jwm6rBXglLlj6sgyolquLXh6A9QGLUT0e9epiu7c9JK7rWweE8ElMlUBM',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyUbzqBQaJ5DZ_hRDb-wdoyOgWx1hg4gv52iKuy=mo',
#   'userName': 'chosyah MR'},
#  {'at': datetime.datetime(2021, 11, 19, 8, 50, 59),
#   'content': 'Classroom ruang belajar yang bgs:)',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOEyUIXt10fO_3GfCc0WIe3wW1x1akfS-tKNkqa0RFk9500Ux0a_CAHMBskuYmkjNC5PSkFtD_xtTmdJrrM',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhERn4HrmRfamONSW01v-qw0ThFFpvwyiiPhY7p',
#   'userName': 'ayu wandira'},
#  {'at': datetime.datetime(2021, 9, 15, 1, 52, 15),
#   'content': 'Pokonya terbaik deh, dulu lama....banget kalo mengirimkan tugas namun sekarang bagus pokonya, Cepat banget.....',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOF21IeGNlIqFUP3PTXsQIt-lMjVPZ9bL5c3Bwk9pJ-SXxVsq9Yg89VCivj7TMBi4ywDKRsyVdD1PJDV80w',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjTFgx_-XUM6RHEgsVWH4SykF0Z98Im2yTS9-APVA',
#   'userName': 'No Name'},
#  {'at': datetime.datetime(2021, 11, 2, 12, 46, 4),
#   'content': 'ini sangat amat aplikasi yang amat menggokil mwehehe',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOF_eJj4DtQRHz54uXCxDenX1pIyyd7dhXQTYokdgk59oI8E5RHXrqkqocju27fTGATejKmrtFKvUiNJ1lA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjuAdPBh9gCQWt-rjDLkw_WSJJp5cO1Pbfr-3rKWA',
#   'userName': 'Devano W.R'},
#  {'at': datetime.datetime(2021, 10, 20, 2, 17, 59),
#   'content': 'Aww, bagus banget. Tolong segera sekolah tatap muka ya wahai Kemendikbud, muak gw ajg.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOEkpXb-yDkgOHo2dRz9cXStyZ2KFzTv4LXhFCICxZrThpODk7M5weMGRPNWm_W_SMWlzP1mXm6ZedjJQ2k',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhzbNdvDx5awX9OlSxp25s1Yu2-WlF-RwwcvHYJ4Gk',
#   'userName': 'Fata Nayla Rahma'},
#  {'at': datetime.datetime(2021, 10, 31, 13, 20, 34),
#   'content': 'Kok di update jadi tambah eror ya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.4',
#   'reviewId': 'gp:AOqpTOE5Q3hXIBuIopjg5uIygnVUmQh1V-gRMCNx3tLo1ywIfT2IFOzIyy_P3pVNTTWKPt93Xw8ZjNuDWgGRRCU',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg8x7ekO25ezdEIcQjq2bypDaLHNKQ0TQYfyvhdNA',
#   'userName': 'Nur Rohman'},
#  {'at': datetime.datetime(2021, 9, 14, 14, 18, 37),
#   'content': 'Kok aku ga bisa mengakses file sih kan kasian tau aku ampe nangis sendiri gabisa ngumpulin tugas tolong dong jelasin',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOEE2ad95Ud4aucJdbP1VtzLRjZfobd2ziXgZmNypLWoq4zNKcs6Bx0kHYHdd9bVylyQYGQKcNwqQKosWa8',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxueVXllTOegyiHnG1WnKyY94x3euPe9-wR0vlA=mo',
#   'userName': 'Man Sengkol'},
#  {'at': datetime.datetime(2021, 10, 13, 12, 33, 3),
#   'content': 'tolong aplikasi nya segera diperbaiki karena error mulu tugas saya tidak bisa dikirim jadi tolong secepat nya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEzbtWz-qagXtUNRx8K22HWJ6cc3k2ww29i4bhNzS_hkYrdAs6B7_DgVSR9faWzSlfnYgAWqZF3aatY074',
#   'score': 3,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjgL5LIswTiSLX3Eqxo5DzWPQASGeh9F-dmsjGNbA',
#   'userName': 'SYAFIQ'},
#  {'at': datetime.datetime(2021, 9, 17, 4, 49, 56),
#   'content': 'Ini kok pas saya mau pilih akun kok nggak mau dia ngomong tolong periksa internet kamu padahal saya ada wifi',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOFOjpvQav81zT21alE_ERafWHxlXLo0QQlKG1tH2oKayRKMq19tNgySpYA097bMNDhJa94n5mgECSs2w60',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjR0wZn8UNUNpU1CzrfBsieW0nLj-m8dI6NYr0',
#   'userName': 'Ari JJ'},
#  {'at': datetime.datetime(2021, 10, 15, 8, 23, 41),
#   'content': 'Lumayansih tapi terkadang sering terjadi kesalahan banyak tugas yang enggak bisa terkirim😥😥 mohon di perbaiki 🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFxLvo_npY0_fIaxCAu1kuYaDsFagJYwEO1O2GeS5bWMJygoOWCB2sZX_Dlisgc3P-o5gUZckJkH46mmCY',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiWnLPX89mWq5oOQ2RyYDi-YWnxAdKpEeAPAd8x',
#   'userName': 'Rizqi Amelia'},
#  {'at': datetime.datetime(2021, 10, 19, 2, 2, 8),
#   'content': 'Kenapa 2hari ini tugas yg ada di GC menjadi file Drive dan tidak bisa dibuka? Tolong diperbaiki lagi',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHOYRPanhyGOWpPwqYr4J8gfoiA3gxdRM4h_mbzhAeXHMQFsUm17AISg9wAN5NzlpSLjM2JBomwM9yWMmc',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghpz5oOh1Sw-Eo75vTwR7hQq4bAYu8fer-8zFeOLA',
#   'userName': 'Thabita 2A Nabila 3B'},
#  {'at': datetime.datetime(2021, 10, 14, 6, 25, 29),
#   'content': 'Dasar google lelet, video nya mau di upload ke gcr tapi malah gak bisa apa lagi loadingnya sangat lama 😡😡😡',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOH67X9ZppSNyXPk2vmhjI2wdEF8GSGWq3F3DavUMfPSmxZ9f16UJF-Vq81LqtGHXNgPBPgadeYkzKtDg08',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwI0E_i1kjLV0BjgGJO_Jg8A2YNLPVR6e6pBDJC=mo',
#   'userName': 'Su Cipto'},
#  {'at': datetime.datetime(2021, 9, 30, 7, 20, 14),
#   'content': 'Maaf ini saya kasih bintang satu sebelum ny ingin kasih 0 tapi GK bisa,jadi plis lah kasih batas tugas,ni guru saya ngespam tugas Mulu plis perbaiki bug ini',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOEDMeQk95rEqvkaQnuMCPFsLGIrCEadPA-d7tiamLAI9PAKfAJjSARwB3PwAwyPYHMcDTvIb200TzfqoHY',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjJiALzjHNXFwlOpeoDw5feWpHdxBJ0RFkzHWTfAw',
#   'userName': 'NADZIF_18'},
#  {'at': datetime.datetime(2021, 11, 22, 3, 36, 30),
#   'content': 'You know lah derita pelajar online',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOH2ODAKBT6SIWeFlrshAVlIeQnjZWetgcdHAqlG3x46rz6uV0zUW4bDWPDIAJWPGr09fk4dXwZPo6VCSzw',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi8dk5qGVM_RuC4B-e-K5Lj8lUIxBQKGnCGOn45',
#   'userName': 'Nice Boy'},
#  {'at': datetime.datetime(2021, 11, 8, 10, 4, 23),
#   'content': 'Kalau ada bintang 10 saya klik.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHofnk89EY1AurJhc7LUgMCNZPHN6LRsrhJ8l4hl8IGVHg1rcZHJMCkb-4yxwAGL3MDCriZDP7U9dYdfkA',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjgPVq1WWSnK-mb6FQdlMoDQSown_egLPvLKOQZHQ',
#   'userName': 'Lukman Hidayatullah'},
#  {'at': datetime.datetime(2021, 9, 30, 4, 26, 28),
#   'content': 'Kenapa classroom punya saya gak bisa dibuka ya tulisnya harus diperbaharui dulu padahal belum ada pembaharuan diplaystore',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.1',
#   'reviewId': 'gp:AOqpTOG0i9OzzuhTsmRZzBzENkgLJn8YTJYO5cJGLUbmLs0aTKv9Nu7sMfxsuY-DfMMxhfEsnXY0Cvwk4aO6ejg',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhqYKevrixy2j-YnJxCE8eTYXjkxu5zHwJ8LgMqfQ',
#   'userName': 'Raheltheresa Simanjuntak'},
#  {'at': datetime.datetime(2021, 10, 21, 14, 43, 34),
#   'content': 'knp sy gbs upload tgs ya, tulisnnya "tidak dapat melampirkan tugas, coba lagi" gmn mau ngumpul tgs anjir klo kek gini d marain guru gw ya allah',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHOOhow4O2UEa7Q8cQBxIobSbewGzbX2CyiKeq5MqcKuCIh4kgB7yXAEusVLx7ES0_OKyHcYKFTahTlqbI',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Giq9PU4TdtOIqYu2daquAHGceLMFFINLzm1pzLT',
#   'userName': 'Firyal Cindana baru'},
#  {'at': datetime.datetime(2021, 10, 21, 0, 9, 38),
#   'content': 'Maaf in apk nya lumayan bagus tapi ada bug notifikasi tugas tugas yang sangat banyak moho di hapus bug notifikasi tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFV-lZrzJm7sMqg10Kp48z9RmyQ7qq5LZz_X-ffcZtU3pwdi9ccng27ChC7ETTJZHHUqCJd1FY0UNpJleE',
#   'score': 1,
#   'thumbsUpCount': 0,
# ...
#   'userName': 'Nisa Nuraini'},
#  {'at': datetime.datetime(2021, 9, 30, 10, 32, 17),
#   'content': 'Ini classroom nya kok kembali kembali sendiri?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFs2rP1JAH1t8nLMPHQo8eVfPaRJjf9AcuJ5h7zn82NyHt1JEivv8jyMj8WgTbkKs5CBGwwrzjeeXimBIM',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhGagK1sKIoRnVGWsGc9bB_uM5tHJBc3ouKdS3m2w',
#   'userName': 'Mrsh dewa'},
#  {'at': datetime.datetime(2021, 9, 20, 4, 26, 37),
#   'content': 'Terima kasih sudah menghancurkan kehidupan saya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOH1chg7PB4DzHUtOiPo9zCGy5u0lFBLLn-M8WHq5kbZzsUEquUnKTOwK261QcyN55gkOlQ-EQXwIpD0Nv4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Giy2LwlGe0PMEqHPBGBeyGI_aYPZZ9PzmSDe651pA',
#   'userName': 'Shine Armadana'},
#  {'at': datetime.datetime(2021, 10, 12, 6, 42, 43),
#   'content': 'Mohon diperbaiki, kok jadi file drive semua',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFl1d_3D0Hxe3ZVn-0tFNitgz6dhYBBt_C3DAybLkR-xpC3ixbDfGFihXKjCoteqsx6WqphDq5-GgOdtdE',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhGBdtdi9m5lhynsPAafrA9o0l6pnT3rpJVB6ywkQ',
#   'userName': 'Ilham Ramadhan'},
#  {'at': datetime.datetime(2021, 11, 5, 0, 18, 32),
#   'content': 'Banyak tugas hemmmmm',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOF-jyKBK8vREnMSH7iFqXL0tIVlqdPPektg8ytlzN8wnXKnEBCAJnMRUFfX-bejNxiSx740zbj8R3fvHHw',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj7o7uyZmcM3lWsJgt8D5lnIhGVso13HNI0ZT4dSA',
#   'userName': 'Herlambang'},
#  {'at': datetime.datetime(2021, 9, 12, 17, 3, 16),
#   'content': 'Bagus aplikasi nya,tapi tugasnya susah hehe',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOH7CReeUIa5IPtq3TeqoZbZacT7VWJRPojcFakATP5gJP27RZLD90CA-0FbPUPKsSrq_-LWrHe8lx11uHI',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GirskQJJfDhfkbqlQRAGSEgvuExIhbFgHOPmwrq2A',
#   'userName': 'Fakhri Gaming'},
#  {'at': datetime.datetime(2021, 10, 2, 4, 22, 19),
#   'content': 'Meresahkan!! Tiap hari muncul notif tugas😌',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOFX1DYnnjuzjQiprHq-lKcVGiP-3j7cBclJh-W-R10KO_BrqOlfmCoUAHI8Ro7c_spelVBaaDnxD6FZbpY',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjxHgi_mhq84hGbOdwx7dUtlzUTwK5S2OZCc54-PQ',
#   'userName': 'Luthf Irfan'},
#  {'at': datetime.datetime(2021, 10, 19, 23, 37, 47),
#   'content': 'Bagus banget aplikasinya berguna banget!!!!!!!!!!!!!!!!!aku kasih bintang 5 deh!!!!!!!!!!!!!!!!!!!!!!!!!!udh jangan liat ke bawah kan aku dah bilang aplikasinya bagus banget!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.33.03',
#   'reviewId': 'gp:AOqpTOGs-tFWOz8ZNERTe1cgSsS6KW2KbYpLpWyoG-YLfbwqfnH2v2VPWOhu5DG9TTf0ajq4x-7IdKWGqtAAfOs',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyrlY1EyOq0bZMPyviz7kCU9E5-Nl95rSKMnxeR=mo',
#   'userName': 'Desta Rahmawati'},
#  {'at': datetime.datetime(2021, 11, 22, 8, 56, 58),
#   'content': 'Senang belajar dengan classrom ini',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOFosz0_O_fHoXExoui723LBWNGxa8BNEfX46PPWgYB8HTNTxMpqlkqgyubGqSBcVxXVpmXS2bDI43qyStw',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg9lERvBQFCAhbY0L6tXosn5sFTe6VfecRAvdOSew',
#   'userName': 'RathiAni Vlll.B'},
#  {'at': datetime.datetime(2021, 10, 20, 13, 20, 47),
#   'content': 'Berkat anda saya semakin jenuh sekolah online:)',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOH5mVAAii3frcwDPtmeTKeCpPHNE8Abyxr0MaUs9H3679sTSna4gRw0Z_KlflXCFemou-urjPKcMM_NNnE',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GghOM-Q7ZYwmNNFOCc0LkfKOSGbIORfnPD2Obo5mQ',
#   'userName': 'Rivaldo'},
#  {'at': datetime.datetime(2021, 10, 4, 1, 1, 45),
#   'content': 'Aplikasinya bagus sekali bisa membantu sekali',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOE0_WtrZtIzW2ibCCj1cVTDkt9qw-q6x0bqay0sUYLbdE72PWS0N9WiWOvnA-cP5Tw5rJi_X_7w9igjCkM',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhZ296OmnecsahL2bcSZKLcP_LEZ2IhJfatpzovaQ',
#   'userName': 'CINDI RAHAYU EKA PUTRI 11'},
#  {'at': datetime.datetime(2021, 9, 30, 4, 45, 25),
#   'content': 'Orang yang rate bintang 1 masalah nya apa sih',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOEcYI_vpGi7t6p1gc0A0lJKne1s2YIpYmLefMMalv_kKog7EXnfIA5l4bAYt1CHyoHPcrEExm5LkdQh_7Y',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh9tExOvd_RckHPjwM7uyJbBvNdoP5i7QX714GLnQ',
#   'userName': 'Jose Ricardo'},
#  {'at': datetime.datetime(2021, 9, 10, 23, 14, 41),
#   'content': 'Aplikasi ini kurang rekomended sering keluar notif tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOG5dPkkjCGTOPmR_jV-LmjJrJkjMcJFLUL1XjFVhfAnSgmNFjz9Mexned6lN9JtnmAz9arFs7ITksAOdQE',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhlO5u2nHyFuRTkrQxPzButyMBB7C9putQu03M-rw',
#   'userName': '33 Rezaldy Bagus Pramana Sakti'},
#  {'at': datetime.datetime(2021, 11, 23, 8, 4, 43),
#   'content': 'Tolong betulkan bug kirim tugas video lama padahal internet lancar',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOFzjd4JzGmt2jAtMXGAEqG_4wRkU0TBjdXKR7GOl7N41h4cZn2OHpV35PLRLq_7AG0Av-NZR781WHPdoI4',
#   'score': 1,
#   'thumbsUpCount': 147,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgJlhNdHwPO4JkeIkxx5ZzT9FgdTBI_8QZsqhgBBA',
#   'userName': 'Iqbal Herdiansyah'},
#  {'at': datetime.datetime(2021, 11, 5, 11, 49, 32),
#   'content': 'Gara - gara gua daring jadi stress',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGg5PCjEU1RM3C8c3Q6JnnrVGQNlwbwER22lXPCdj0fETfa3HflmGdhi6zj3EzpMVn1wCnMRNedTRfKeU8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggs86wHzUNb5_Vx57XUWIZhT1ZB3EmhiXws_qxWOA',
#   'userName': 'Adry Sihotang'},
#  {'at': datetime.datetime(2021, 9, 28, 3, 28, 49),
#   'content': 'Kenapa abis update jadi eroooor ???',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.1',
#   'reviewId': 'gp:AOqpTOEUWPUOguAAvIqX57kejiNlxWNYTjsIgyIUchraEHXtcduTsc6m76vMmMJnex1gENw0G2yspDt9f336dg8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiT-3W8SgA-XJWmq9-Fe0fSJnlM73p9wOCSbd95bQ',
#   'userName': 'Dio Alfajri'},
#  {'at': datetime.datetime(2021, 10, 6, 8, 21, 27),
#   'content': 'Apk nya keren banget!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!Tapi Boong hayukk palpalepale adit nopal arpan raka surya pristel kalo mobil #Chuakks',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.40.03',
#   'reviewId': 'gp:AOqpTOE330aQIGZOa23FRKLDfTFxR4MbA8iJrg44RXZi0ZI1aajLBFfhXnqp6pqNNWIx9xcptbO47CT9e4qKKDo',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GilIfJMZMaq8YzZbY5foy5chYT8B3BGHqCESO7Lag',
#   'userName': '09_ Aryudha'},
#  {'at': datetime.datetime(2021, 9, 29, 1, 25, 2),
#   'content': 'Tiba tiba semua kelas ju di pencet error dan hilabg',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOH59HjVaXn8JjcAi3emo_HeWHNfQmhoxyUKy5KhPtkSylYL_ze8YXNHucfOAeIpF1aVlfQ84WEtBAM8Bws',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghw09dUhau0Aqad-rHmgONfuFo7cQbWGZCUmn68ug',
#   'userName': 'Vaiz Akeyla Kenzie'},
#  {'at': datetime.datetime(2021, 9, 28, 1, 12, 11),
#   'content': 'Asw,apk bermanfaat tapi hari ini error gabisa di apa apain kentod',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.1',
#   'reviewId': 'gp:AOqpTOFHjyR0_5eDg5tsGrUBCpoCBGAGAmH670A-Zijd71FzOKP00zHgWwkDwy5pxBsNl53Wb-oflqorETmsICQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwkjOXI2m5AN72vBhB-2MlT76DC0IdZMJCswP15=mo',
#   'userName': 'erh juan8'},
#  {'at': datetime.datetime(2021, 10, 13, 13, 18, 21),
#   'content': 'MKA KIRIM TGS TAPI GAK BISAAA, absen juga gak kekirim, kalau alfa ka kau ku salah kan >:(',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHJgEUh-mwIBG58wvCFQTT8WCZNQDzukXGtm_0wd5ai-oN0PvmR6RdA2Es1S_VVVXnQIUq_ejGRekYAuWY',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiA5TzSfao1MJlL_JLj_2PxTvGTooSrZBb7dkB4',
#   'userName': 'Sa'},
#  {'at': datetime.datetime(2021, 10, 25, 1, 38, 18),
#   'content': 'ketika klik notifikasi kemudian kembali malah keluar',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEElRmy71Xp0udyzhFUvrALzGilX4kaVYks6hvbiiMVww1a7l-j6Yt_SdXCmF13rA8WrPQfE79avSp_qx4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhlA8lgWH2q1Dpv2G9WJI1WyZYF0k6of60eOVw9',
#   'userName': 'Bagas Dwi'},
#  {'at': datetime.datetime(2021, 10, 29, 13, 16, 31),
#   'content': 'Aplikasi yang sangat membagongkan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGt3xliOvUYAlr2-IwJrm3D85J2L8TaiTqqtyMktms1nYH1TAMHIrCszq00luD5hAy-O-TGLmwdiadO4d0',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgmMh7NK9n96u5LTs8tMtPqD_ZOUcsx-LapH26l',
#   'userName': 'Adam Mulyana'},
#  {'at': datetime.datetime(2021, 10, 12, 2, 31, 23),
#   'content': 'Aplikasi yg diadab banget Kalau kalian pake apk ini nanti klean bakalan jadi bodo kaya aku',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.30.04',
#   'reviewId': 'gp:AOqpTOHI5rrw-HkZuO0xY39yHfFES-88qyjSlusTUmYprs0g77vF7N-gm_hMAcjdL3tVFEtLoTNPTFvBxUrgbxk',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GihFNul-rlGBnuqbt-yRUU4dpDjWYFlXZg1SWInVQ',
#   'userName': '7.1 Thomas C.P'},
#  {'at': datetime.datetime(2021, 9, 22, 14, 12, 11),
#   'content': 'Min tambahin fitur bisa cari mata pelajarannya donk biar gampang nemuinnya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOHmRWEvNiJJ48vGw6J2UaRblAF1WfQV-teaEnFkbNn4RzPZYnmaWy04KQkM3Y5-xkleXZ0DZk1FuYeP4SM',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjQ5fKDrj8IlaxCEaONzq_Psbe27DKY-WokjWeMwg',
#   'userName': 'Muhammad Rama fahreji'},
#  {'at': datetime.datetime(2021, 10, 16, 1, 45, 28),
#   'content': 'Kok buka file susah banget padahal sinyal bagus',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHKGw9DyH5gysVaYuuTmNxDef0NVpZwlZwUELQbm94cLvtNyToRJWNAoc59qlkeVpIRqnLi5JgOUFD8NFU',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwu8iXTYeWfyWlMQ9k2lAMYCPNrQuBV-YNEp6Vh=mo',
#   'userName': 'Pemas Dwi Ramadan X TKRO 7'},
#  {'at': datetime.datetime(2021, 10, 8, 3, 5, 33),
#   'content': 'Apl ini membuat adek saya mudah untuk belajar',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHvqSXmUqcX8vVGWfprjzEzlWtoB0ZWBsOSVMIlmHH-dGNZqzAO9ritViBFsHQoUCs6Pd9If7seTKPe-c4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh01OSy6WW1875T2cJ_plOXjSFsYvgZIv0OWpT7sQ',
#   'userName': 'Wipri Koplak'},
#  {'at': datetime.datetime(2021, 10, 14, 12, 14, 15),
#   'content': 'Kenapa tambah diupdate tambah jelek ya??',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOE8Vi_rtPULkDvIi4G44JlqXWL2Li4k26LAYaic-vZXgJE5xeVQwnfA5S3Sht-fatDagqVBzpwfvila2_Y',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz1QrfxMJjk9UmxYxQ26MVtAw5UkS3ug8dCZ2Q5=mo',
#   'userName': 'Rani eka desi putri'},
#  {'at': datetime.datetime(2021, 10, 14, 12, 14, 15),
#   'content': 'Kenapa tambah diupdate tambah jelek ya??',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOE8Vi_rtPULkDvIi4G44JlqXWL2Li4k26LAYaic-vZXgJE5xeVQwnfA5S3Sht-fatDagqVBzpwfvila2_Y',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz1QrfxMJjk9UmxYxQ26MVtAw5UkS3ug8dCZ2Q5=mo',
#   'userName': 'Rani eka desi putri'},
#  {'at': datetime.datetime(2021, 10, 18, 8, 39, 52),
#   'content': 'Ini pasti aplikasi kalo saya pake selalu error👎👎',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFnpjx6WFAISqFP7x-WRg9ZEdNUUSj19T1MdtDACsygsd7k8BiWtyuVOi4YHnrhR2e5vwQwoNWqxKJKRKI',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyqR3canGAKXk_rcs5Buy0K7T2j3uFY9R5P7b6t=mo',
#   'userName': 'Atik Nuryani'},
#  {'at': datetime.datetime(2021, 9, 30, 8, 14, 26),
#   'content': 'aku suka apikasi ini iya aku kasi bintang lima',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFDvbf0IPClT8kHtTcYkeF9G9UdnjpaYIPV3gJbzS-edWnADnsS9r8SQWxoLwYgy5pZCsumAtOMbbrQR80',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj4oS5R6PM7CL6Q-gzL-BVt6uUF_TSA42YP_ogL-g',
#   'userName': 'Naswa Putri Aissyla'},
#  {'at': datetime.datetime(2021, 9, 30, 1, 44, 58),
#   'content': 'Apaan gw coba apus lembaran malah bilank"masalah mohon coba lagi" PLISSSS DIBETULIN',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOHqpPayLvP_BQbnPfv-wpCBf1EMVjOtxJ5saFZqtE-VsbQ4LeVnfRUKJlNtS3lrQZqWD1bYALs2xuPIGHA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjuxCMzVYgcMCHqXYN0F0tojC1W_YCVzy-iPByp',
#   'userName': 'ALBERT X'},
#  {'at': datetime.datetime(2021, 11, 9, 11, 44, 53),
#   'content': 'Sangat bermanfaat bagi orang bnyak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOF5FFrvD2-xb8h7-tsQTHZlrUBo8rysTdABYkS-ONaOEO_Nx4zhSvcSXtIn_oCp_uHtpDFSGmIs0q9DIv0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhHzfBb7nDPg1EnKZ-l4HiS26XcYqzDoHtB1weY',
#   'userName': 'Ayu Lestari'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)

# %%
df.to_excel('Dataset.xlsx', sheet_name = 'New_sheet')
