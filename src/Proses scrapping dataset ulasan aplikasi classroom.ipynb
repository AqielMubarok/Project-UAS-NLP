# %%
pip install 'google-play-scraper'
# Out:
# Collecting google-play-scraper
#   Downloading google-play-scraper-1.0.2.tar.gz (52 kB)
#      |████████████████████████████████| 52 kB 1.1 MB/s
# Building wheels for collected packages: google-play-scraper
#   Building wheel for google-play-scraper (setup.py) ... done
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.2-py3-none-any.whl size=24393 sha256=1a213f3206eb970690712d0245f949e9b0b2f30838db51367f09b2d4c3226b69
#   Stored in directory: /root/.cache/pip/wheels/98/99/eb/bbb9d24a5c526980647efc10336eaaeffcf07749f581111128
# Successfully built google-play-scraper
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.0.2

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.google.android.apps.classroom',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=3000, # defaults to 100
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.google.android.apps.classroom',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
result
# Out:
# [{'at': datetime.datetime(2021, 11, 21, 17, 53, 5),
#   'content': 'aink dikasi tugas video mulu lah',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGElIpE5jTEldUh8hBrWELHjigCgmNtAaG7qhYhb381i5x_R5UD5y-AQfP6PUTgblMa6IXfTu3n50RsHdI',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiBARmytwy4F1J1eyuUjBGekqg9DEtSmOm74j-B1w',
#   'userName': 'Karisma Bintang'},
#  {'at': datetime.datetime(2021, 9, 11, 6, 22, 22),
#   'content': 'Bagus apk nya, tp kok ada bug tiba-tiba ada notif tugas? Itu sangat menggangu juga membuat stres sekali... Mohon di fix bugnya🙏🏻',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.03',
#   'reviewId': 'gp:AOqpTOEZIbAzSeCMpBtHZbdybCllDHmfqmnxGSKVBcusFsS3Pr3WAvKt-aHGSpz8_fu12mQ6odkh4aAbmhz8SYs',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjXnJYHMKrfQAx-oJC8vt4C_8lBypGoSYRukZ5biw',
#   'userName': 'Andikha BDG'},
#  {'at': datetime.datetime(2021, 9, 10, 9, 36, 1),
#   'content': 'Yaahh... Kasian bljr daring 🤣🤣 pada ngeluh bug yaa wkwk',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOEXvW--M-RaiK_y1NEY8q_tSJhKntMSfZ42OxYdiCjuQ5lTuXcIAfUM-hzW9dWD5D6P2ECCDhoSDzPJkrY',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzAN-g7AECdx3JujsXVsxewCKrdZHl1qxgpzhCv=mo',
#   'userName': 'Ridho_elghifari 24'},
#  {'at': datetime.datetime(2021, 11, 8, 10, 25, 54),
#   'content': 'aneh mw ngirim tugas pidio malah gabisa maksut amat',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGJQW_XpvRlnjlgjVMLuOLismXueXTKNBipk3VIkaKSa4AemTwJOu7V11VcFVgm8ZVNorjslF6G7qb2v9Y',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhP4GyeX1jivPue1gBRYfdMeGIkfobrbtBixEWIWfk',
#   'userName': 'Elza'},
#  {'at': datetime.datetime(2021, 10, 5, 2, 28, 29),
#   'content': 'Terimakasih berkat aplikasi ini saya jadi juara 1 di Dunia makasih Kepada pembuat aplikasi ini hebat banget sumpah ,saya juga dapat menjadi calon presiden',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.40.03',
#   'reviewId': 'gp:AOqpTOFgANAPZdMG1TUzNkxQ82s5IR0KAnBze-uMZRPLhQMKjosNmFdwvfYAyLXplzCEKVKm04CFOCoVBcbVrC0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gib1XMnR2mgvlPEU3QUvT40Tpc4bgudIb8Kppw2',
#   'userName': 'big smoke'},
#  {'at': datetime.datetime(2021, 9, 7, 3, 36, 57),
#   'content': 'Mohon maaf ini kalau kirim 1 video sekitar 10MB lama memakan sekitar 3 menit, apakah anda bisa memberitahu aplikasi lain yang sama dengan classroom?',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.34.07',
#   'reviewId': 'gp:AOqpTOFpbBx2yaqc3Y5pGmHEs_HMznV60_RIrtm7T4sZ-4BI6Yu7hJDJMtC-QupVORBTvxmoqacBDnPoZbY4mrk',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggm9XZjsNBSLiy9aMgujYUs17uDaAPIiJMHdD77BA',
#   'userName': 'Fatima Azzahra'},
#  {'at': datetime.datetime(2021, 10, 2, 0, 45, 10),
#   'content': 'Ga tau lagi aku',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFEqqRW4BSHY77Lysa7TV9CAizSb_Vfv9D-kfVLDxOQaPycETVIHeShaeeLdfDWYfEbJtMpHzZvPiObG_Y',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhzkaauC8ZmdZiYDtysmhyeslN6wcHEsKHF7sPM',
#   'userName': 'Keisyah Abduh'},
#  {'at': datetime.datetime(2021, 10, 1, 2, 30, 13),
#   'content': 'Membantu sekali',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOEGF8cWfay_eRxH85R_SMydTc--7tvxK_Wpj2NEOakhLQIwSdBuRsmwsblLhaV5PV98mIHWeFMyRj8zOYo',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgHQ8iZzVV_ec_RrYQ7ToxO-DV5zPf0q4Y7CAmgjA',
#   'userName': 'Jesslyn Felicia Kawiharja'},
#  {'at': datetime.datetime(2021, 9, 29, 12, 45, 10),
#   'content': 'kelas nya gamuncul',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFsSEd8t-i-nihyKtd5DYO5_Nxk4koBA4GTzvg1p4sFuajetegALNBQWMEyT0Ve9aZUPvc-kUZPFv6AbhQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzD5RGVR05o7dNc1eJsBxjYHCs1DMO-99P3Zwgi=mo',
#   'userName': 'Aprillia Farah Diningsih'},
#  {'at': datetime.datetime(2021, 10, 12, 1, 14, 13),
#   'content': 'Aku punya login🙂🙃',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGghpDqPVz7asS6wSXiPrEcUvInW7YIDnkr7Y9DQ7ghz6a163lSPpKIQvB7D-xFqQ5oeZ2Sfeg6_20k2bI',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiOWm7WEJkQ9kYetLvLFgKEI-FL_kQlLsEiQV5UQUE',
#   'userName': 'Sri Rejeki'},
#  {'at': datetime.datetime(2021, 10, 8, 12, 10, 58),
#   'content': 'Seru banget gan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFK6KS4vFP5fiWhajmUGasFrWIxoKl43ZswRNnkn2Gg4aB-YA8MZr0RQZHE6mLndacjhraey4cpD2B5aVY',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgwRK_gJvgPgDTY5-046OE-PlwZb5kjyur1LUWcxw',
#   'userName': 'Ahmad Raesah Pratama'},
#  {'at': datetime.datetime(2021, 10, 4, 10, 58, 32),
#   'content': 'jd banyak tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOETCo-nUvm7jwCCiqfA2bWu0kKISaekRwiQtK9vJ7lHwgb-3aB6Jc5XsKzRKGwoA06cAvgVp8jktydAv2o',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjfE0_KceodsPSiTQ6BpA7SaELUYCFYmTiEYAZLpQ',
#   'userName': 'Kayla Amelia'},
#  {'at': datetime.datetime(2021, 11, 19, 23, 36, 3),
#   'content': 'Sering Ngebug Notifnya Kebanyakan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHNFnwYp6mOV-DpZxYAxmkQVa2jhbruRsv_oF5_VZ1I_BSeGEDD5fqZ8AXIRE1Azy_KR1Xxw573Xi3NvTo',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjKo0xAZQZf6BiqTft1MgOFl-xYekFJHKic-CSC',
#   'userName': 'Kiriha'},
#  {'at': datetime.datetime(2021, 10, 28, 4, 18, 57),
#   'content': 'HMM kurang menarik bnyk bug',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHcN9Ep417DjQorlG3s36vezTus6nVlXQPr8tycby7yEQ3afEq0mMPxB5IpdY0r4lO5-s4duo7dHm4EbLQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxiP8PwYyghyAwgxu949ZGMnJWoktN_alY6CwQB=mo',
#   'userName': 'Ariff In'},
#  {'at': datetime.datetime(2021, 11, 1, 18, 45, 51),
#   'content': 'Saya benci tugas👍',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOF0jthrvuHzXx6FUd1gIp9b05-7KsWhvxhKz1AwyS7h3J0n1yyYIvnP4CJ5zT1dDp144EhEwnh-_HnUvpE',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgXorXkVZH24CUbIzvwTC7hxAt2DZZY0MtiGgNj',
#   'userName': 'EKA TMG1369'},
#  {'at': datetime.datetime(2021, 9, 16, 2, 46, 51),
#   'content': 'mau ngirim pdf gagal terlampir mulu heran',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOGKu5SprMxvsb-geTMjy99JAp-777w0-alSsJh9wcHkt4kaxiN1yfSr40kl9k8vlCTEabFBemdnNNJviIY',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiDoyb52UAov43eM0zybazheE7ax3yDcjap7uzE',
#   'userName': 'Marshmalo'},
#  {'at': datetime.datetime(2021, 10, 12, 11, 47, 1),
#   'content': 'Yah, eror bang',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOH33kzEjC4fAB6SLeLTQKr9vunf8etsCkqbgcUlTgotcbHWXMm6yUsNofr_VQHRUtNO-dvSAUv1bZCieNo',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj5rScKh_UmcsUAtQe5blgBg1L7z89IWXl1Sd-CfQ',
#   'userName': 'Frendy Setiadi XI IPS 2'},
#  {'at': datetime.datetime(2021, 10, 13, 2, 14, 28),
#   'content': 'Lumayan lah ya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEvwk6ywcwUKOIh7JKKbZr4BwbG7z3UORkJmgCKmptIUSFgsbQDaYF7ALjo3HIuPOn81tOl73cYq2yjHDk',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJycTHftZAUk0PZb1ob6NZS3Ol_HQpANazkNnlGe=mo',
#   'userName': 'Anisa juliana'},
#  {'at': datetime.datetime(2021, 9, 21, 0, 41, 34),
#   'content': 'Aku suka belajar 🤗',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOG0oDpGxzdpnVTgN9EENEEYh1nnuRLWO-e5no5UWnizH5BIi5dOGPdHaeQTYKDbzVSPBUPVwDgweYEM-K4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjfccT26FpDfu7fOQUzecSX7Vw70nKw3TxXWxbuNQ',
#   'userName': 'Dian purnama Sari'},
#  {'at': datetime.datetime(2021, 10, 4, 2, 0, 26),
#   'content': 'Buat pelajaran',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGIzNdd6paZfjfoGefAd9hA6oayNgywp4HDedxxxecOWqT6yVaxbrD2V915JvMRxwpnIa13WrLmykodOSQ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhvJ5UiCg8tNUO7UWFyNirFyDKrUXe9dPVJKg8M',
#   'userName': 'Keysha Almaheera'},
#  {'at': datetime.datetime(2021, 9, 30, 6, 30, 30),
#   'content': 'AWALI HARI MU DENGAN DI SPAM NOTIF TUGASS 😄',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOHjOrCaBiGUEZ_U7-0o1d1t1YpcbIr9bXggSI3qXuS9fVqGw71E2GlDW_JB_wnFrKE0sLPc5Vtfyyxutcs',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GghBjAMfoGX-E6AA8WmgHAjyIctZsMjaZO8MxVxSg',
#   'userName': 'saka wardani'},
#  {'at': datetime.datetime(2021, 9, 28, 6, 13, 19),
#   'content': 'Baik dan bagus',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOFmY3HJIUdLX9hwyt4G6SqA70CNj8VqvDLg16dZIvjWVG-gmleBR3Qre6_xPq6q4oqEBMjNXqe14TdTWB0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyhTuFuj3bAqh3LYrjGyCgtva280Pa9w25VQgrK=mo',
#   'userName': 'Amal Udin'},
#  {'at': datetime.datetime(2021, 10, 4, 4, 35, 37),
#   'content': 'Bangkrut aja gan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGXz1ZvwUE6l_luSjmHL4jA_gZmHWgJ3JiGTI1DrfXUaOMkahyI2lYP_bZni30NttVURyg9fhS8KdsLCC8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjosLYpWPKH3w6sNXBA0WPXy4XzKwoKD5_ZFX6AKg',
#   'userName': '05 Davin 8A'},
#  {'at': datetime.datetime(2021, 8, 7, 14, 58, 4),
#   'content': 'Kenapa sih bug terus, dari tombol berhimpitan, tugas yang telah terlampir dan terkumpul juga hilang dokumen tugasnya, serta pengumpulan yang sudah dibawah tenggat tetapi masih terlambat serta dokumen tidak tersedia, masa harus buat baru. Perbaiki lah tolong!!!!! Edit : Sumpah makin parah banget tugas yang terkumpul dan ada dokumen mengapa hilang terussss dah tampilan juga diselesaikan terlambat . Semua tugas saya seperti ini. Kenapa coba? Kasih solusi lah.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.05',
#   'reviewId': 'gp:AOqpTOF4rv3J4hvRSkblyXZbQeEwhYKTDAHUcmGtkGlZGtaV2LZZorDZsotst_w6ytesevd1XWlf-ZD6q99XuFU',
#   'score': 4,
#   'thumbsUpCount': 447,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg0EUcHsKIjhFYoD0WwkZ8Z6PGhLfx0zMjequJpyw',
#   'userName': 'Ifvram A.W.P'},
#  {'at': datetime.datetime(2021, 10, 2, 1, 15, 39),
#   'content': 'APLIKASI BUSUK PAKE DATA PAKE WIFI BUKA CLASSROOM TETEP MUTER2 APLIAKSI APAAN INI BIKIN ORANG SUSAH',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOF7omQhSam0piEkiRmR35q63qT4bUJnTRhGa1r8Pg7T_kamhkEpCMtWhuhyNvNpkf9Z8alEu8z1iK2vitQ',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzHCMm2RZXAH3MP9ylIVQx98WCsfP13xZMdTzJK=mo',
#   'userName': 'Dodi Bastian'},
#  {'at': datetime.datetime(2021, 10, 12, 2, 9, 10),
#   'content': 'Main gc sangat enak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOG-W3ZvW9QV17Hre7RtRmSMZfGH3OjjWPY9ST8B51w8GDN-4q_3bEWe85YJCWV3Zuwh2Knc-8zLrdIsk-Q',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjFcKm-ls8oDU_kX5pjEBqfa0cJDMSmTJE-bLZ8',
#   'userName': 'nama depan nama belakang'},
#  {'at': datetime.datetime(2021, 9, 30, 3, 24, 24),
#   'content': 'Sangat Membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOGPG1NuymHYxYzHqS67HcUSoV3oVQr7MKYcLrKLgK7Q86PTiHY8a8pJUvXBpe2_GisQex27g4q6FXHK3uc',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjMf3Gh7KcWPIey_p1xMT8LUfYixvl0KBk5NPZyxiM',
#   'userName': 'Ardi Langit Channel'},
#  {'at': datetime.datetime(2021, 11, 16, 7, 32, 7),
#   'content': 'capek jujur sekolah',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOE6DnFVvw0-tDbeu5iOuiRpt3ZNGmrjIg3pvL6HHs_Tse2Tl0ivaIcpzEyHNDR3E62qNKGtmFqOujiZK_w',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjTs56l-c-_5J5F3Vf5T2kAtd2sdAflrAdVPHrmGQ',
#   'userName': 'Nitya Potter'},
#  {'at': datetime.datetime(2021, 10, 17, 6, 54, 42),
#   'content': 'sy benci belajar',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGxhUkj_T8PT5l8m3MwMvvkFqvy63NUwUsi3zlmjkk_fcytR9J1jE5v7PvP1fpM6P2lY0XlJ_9z7U6ktLc',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiS7tJjmzANZvvwdW73Qjnqj4Z7yR-yXIjmJ06Y',
#   'userName': 'Mersindaa Almira'},
#  {'at': datetime.datetime(2021, 9, 30, 10, 34, 40),
#   'content': 'Classroom ku eror, kelas e moro² ilang kabeh',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.1',
#   'reviewId': 'gp:AOqpTOEebk049vAww8rbk1uTCBuCgQPI1hRR6WIJ6BBoHS3ZszMICE--kH8xoZHEVhQS3K5Us0Bb4RuRsuNoN14',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgAxZriyFz9fCUI89NCPL8OCX8CIw9UAIbUgsCHww',
#   'userName': 'Mohammad Zulfan Zakky'},
#  {'at': datetime.datetime(2021, 10, 10, 14, 15, 27),
#   'content': 'Kenapa tugas saya tidak bisa terkirim ? Padahal belum batas tenggat waktu. Google tolong perbaiki google classroom!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.34',
#   'reviewId': 'gp:AOqpTOGiIbJKXh7XVEjlb1gLADxfD7hHLELS6aIDUb-2yebZ34w_FqKDLrwkCOjfNhOrqKGyL6bWc6sfGm_wIoQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgqRir68pHjwBnCGBq2RHsm_T58ON5XUET6iz1Fuw',
#   'userName': 'Deaswyta Ayudya'},
#  {'at': datetime.datetime(2021, 9, 10, 3, 49, 45),
#   'content': 'Tugas muluuu, kaga bosen apa🗿',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOHmeOjqr85CDrSlrDKZ9JC0Md-dgtn1ZrpYuTBnx7oK81B67qWqraVNANn3x3LwH7acQXrjRmnqDBY8eP8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjqzkhwkapwGQkgCyAcBdsfrXpZZWOd9tcD4mrxpg',
#   'userName': 'Melissa Trisila Martha Angelina'},
#  {'at': datetime.datetime(2021, 9, 16, 4, 24, 25),
#   'content': 'Aplikasinya dah bagus, tapi masih ada bug yg merasakan kenapa setiap pagi saya ada notif tugas mohon tolong di perbaiki karena bug ini sangat meresahkan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.04.44',
#   'reviewId': 'gp:AOqpTOEVXyX_S6_NDkN3sKleM-jQ4MHotw6NI18KYn_z1c_58jMdZ4mAAKHYNOQ718dWGLnnuD3iiOwiQ5Tv9ZI',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi3_a1pVDifyb6C25CmmfmARuHRhCRkCkWigmcL',
#   'userName': 'ᗩSᗰOᖇO ᗯIᑎᗩSES 727'},
#  {'at': datetime.datetime(2021, 10, 12, 1, 56, 38),
#   'content': 'Tolong di perbaiki bug nya. Masa tiap hari banyak banget spam notif tugas, sangat mengganggu sekali ini. Semoga cepet di fix',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.30',
#   'reviewId': 'gp:AOqpTOH2lAQbP0BvjJ9-rWOjc439UY8ix_9MWgnwQYDlhbWWj7E_czXFnULF7NkqkcT_m_epB-Q1mQB2wTUOyb4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjjjGfoNaypGhaq7wrk4UKNUWL02OcltAbccoNBTQ',
#   'userName': 'Muhammad Fikri'},
#  {'at': datetime.datetime(2021, 9, 25, 0, 24, 27),
#   'content': 'Memberikan saya banyak tg tpi bagus si apknya',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOG829wIPLOTUdcb54lEv-2sgtoyCDZqP0egL_m57FQZ_-Xv07iGoHYmSQZbEljI0TBifXYqzRn0jPGAFmI',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg8CsZfKsu8H4z2E8g5LmjBO4qbgV14Am_WeXb9Yg',
#   'userName': "Lidya intan Nur'aini"},
#  {'at': datetime.datetime(2021, 9, 28, 15, 2, 42),
#   'content': 'Notif kok telat,, aku yg tugas harus selesai hari ini sering tak terkumpul pada waktunya,, al hasil saya di marahi pengasuh saya,',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.40.07',
#   'reviewId': 'gp:AOqpTOGLB4Jmwh_ASksCTmidr0DyiAGiUgAKBPIGrHJjIskYcZseZBcasLRDgVcc7pN2jLgLQKTChgC9X0_-cqU',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiZuDorDYIVXQp6vMlmxwnII7jb6bt-_fvTN5O5lQ',
#   'userName': 'Nur Safingan'},
#  {'at': datetime.datetime(2021, 8, 13, 11, 48, 35),
#   'content': 'Saya nabila, Saya mau buka pdf yang diberikan guru saya di classroom kok nggk bisa ya? Katanya "tidak dapat membuka file,periksa koneksi Internet anda" padahal internet bagus,kuota juga masih banyak knp tidak bisa ya?lalu saya mencoba downloud aplikasi buat membuka pdf tersebut ternyata tidak bisa membuka pdf didalam classroom mohon diperbaiki! Itu sekian dari saya terima kasih',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.33',
#   'reviewId': 'gp:AOqpTOFLGIWuooQN-BlXuLIjfUL7nbLiHlaboCQX1e38BQ_AONvXNd4zYsFY4co5UIgPuZGGbODycPsu1YTugF4',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyh5mTBKq4MIe86b5F1sDBMQIXPN68sfmt416fb=mo',
#   'userName': 'Ngesti Ngesti'},
#  {'at': datetime.datetime(2021, 8, 3, 11, 4, 31),
#   'content': 'Aplikasi yang sangat membantu. Tapi jika boleh saran, saya ingin menyarankan untuk update selanjutnya, apa bisa ditambahkan fitur baru? Seperti fitur menggabungkan kls menjadi sebuah folder, jadi di Classroom bisa membuat folder yang isinya kls kls tertentu, dengan cara ini bisa memudahkan siswa untuk mencari kelas. Contoh; folder "senin" diisi oleh kelas mata pelajaran yang sesuai. Terimakasih.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.03',
#   'reviewId': 'gp:AOqpTOFyE3XN__BQkQYfwlMq9Vobfs3KxCTqbfQnt2u5YHywGbJVBObx2gboUmnERm30eX3rU6kWvEu1xmHks00',
#   'score': 5,
#   'thumbsUpCount': 196,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxRa01yXS4qZ6HA8NNOiX3v3EObsACcu5oeuDJUXQ=mo',
#   'userName': 'Sintia Wati'},
#  {'at': datetime.datetime(2021, 8, 6, 13, 47, 14),
#   'content': 'Assalamualaikum. Singkat cerita saya ganti hp terus saya donlowoad Google classroom lagi tapi, ketika saya buka ternyata versi terbaru. Terus ketika saya ingin mengirimkan tgs jadi susah banget padahal cuma kirim file Foto yg hanya beberapa KB aja. Jadi saya harus kirim tgs lewat kamera langsung yang hasil kurang memuaskan. Tolong kepada admin ganti lagi ke versi dahulu seperti yang ada di gambar ya...',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.45.03',
#   'reviewId': 'gp:AOqpTOHtVhaOgj5QryEEyVY7OUdp3memK55_angKchXYeH2gmB7i5lM-cB97o1U9g7G1j36m1tO5vKtQmPtP-gg',
#   'score': 3,
#   'thumbsUpCount': 9,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJykxbyHqn1qVPfVD6ujA0uwCJGpgLd75vThp7iP=mo',
#   'userName': 'Rista OR'},
#  {'at': datetime.datetime(2021, 8, 25, 1, 59, 58),
#   'content': 'Belakangan ini classroomnya suka eror, semenjak di update jadi ga bisa ngirim tugas mana tenggatnya mepet banget lagi. Pliss...perbaiki lagii...aku mau ngirim tugasnya susah banget, masa harus japri terus ke guru mapelnya kan gaenak takut ganggu gurunya. Jadi pliss..perbaiki lagi 🙏🙏🙏😭😭 masa ada tulisan "anda tidak dapat mengirim tugas saat ini". Udah capek capek ngerjain kagak bisa dikirim, gimana ceritanya...mohon diperbaiki lagi dongg ...kasian yang lain juga mau ngirim tugasnya susah',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOGdrbVu57I9YDPMU07n2clPQvK2NnFrWt9lO1AS7UrCimkf77vHRZTOt_G9jRppGDeiikprAj6F2g1z53c',
#   'score': 1,
#   'thumbsUpCount': 188,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gh071aN76aM5jboesUWDoBjQ72FtveW4iTl8cg6ng',
#   'userName': 'Salwa Salvia Salsabila'},
#  {'at': datetime.datetime(2021, 10, 12, 11, 4, 38),
#   'content': 'Tingkatan lagi 👍',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFCLid3AJ5DjQFsvqr4mucPhen6TaAlGJmYRdA1Mtni4MQsdT1OlSyhHPkDpqYJNikHbslEN6Awq5EohyQ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjLjTbvlMTvp6y3KmX-FceZ1kAhhcAejiQIOlJcKKs',
#   'userName': 'Dwi Puspita Sari'},
#  {'at': datetime.datetime(2021, 8, 29, 4, 42, 38),
#   'content': 'Notifnya muncul terus, terus tolong perbaharui agar notifnya tidak terlalu mengganggu. Terus satu lagi, tolong agar berbentuk tabel setiap kolom mata pelajaran. Kalau scroll kebawah tidak flexible!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOEimmm4Ke1qeCBjSY8CQGBaQddpy8dSrfuZuYK1BSSsI6TpOPf5cAR1vXD3pTC_BmbTIBODvDg6cFSDB1U',
#   'score': 3,
#   'thumbsUpCount': 6,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi5kugOV7MVXftbPGJ9V-KaEgXt2g14sg2BgsTeNQ',
#   'userName': 'Muhamad Abdul Haris'},
#  {'at': datetime.datetime(2021, 10, 9, 3, 52, 48),
#   'content': 'Woy developer knp sih selalu ada notif tugas dari guru?, itu sangat mengganggu dan meresahkan tolong segera di perbaiki/fix',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.34.07',
#   'reviewId': 'gp:AOqpTOFMxpsRN1vGJt6Ne9rhO97Xwr_jsOC9kF6KhMGv0B_ly3pWadFSvLdozPH6F-yKrlSFR2MUtnknv3Vucl8',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyZ_g7kH0Ey8cvbQhnuAGdEP2hhyt7Z7qCnZB49=mo',
#   'userName': 'Rovino Nichal Dava'},
#  {'at': datetime.datetime(2021, 7, 19, 10, 57, 3),
#   'content': 'Aplikasi terjelek yang pernah saya tahu. Untuk upload file amat sangat lambat bahkan tidak jarang tertutup sendiri aplikasinya karena nggak bisa-bisa kirim file. Saya kirim video via WA cuma 2 menit uploadnya, lewat aplikasi ini sudah 2 jam lebih masih tidak bisa terupload. Kalau nggak terpaksa karena anak saya sekolah pakai aplikasi ini, nggak bakalan saya mau buka/pakai aplikasi ini. Mau tanya, apa ada aplikasi yang lebih jelek dari aplikasi ini??????????',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.44',
#   'reviewId': 'gp:AOqpTOH4a80vp9tA4tMzL14Vl9JF5jWKip8Vv4JvOBkyxoH21r258lGrIO_n6LMbvIlbdJFGDFiO2IHT2dYFgLA',
#   'score': 1,
#   'thumbsUpCount': 14,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiLevHSwK5x8K3lCTHB36CVKBZWMfJ7BYQcgw-vaA',
#   'userName': '07_I G A A Kusuma Savitri W P'},
#  {'at': datetime.datetime(2021, 10, 20, 2, 52, 53),
#   'content': 'Kurang menarik',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFZMaNQx3HWFGfPwJGGQv5CGXZ_fZrkc6vDPTg2-xKITbfuvuNutE9AWl8B6nQ1svVfMVJH1iiHGN7muBE',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz54ucDnWAef73aAldp59XEE2tcrWzO3wyx_Rdx=mo',
#   'userName': 'Yuli Zulaikha'},
#  {'at': datetime.datetime(2021, 9, 3, 8, 28, 35),
#   'content': 'Sumpah lemot banget, padahal jaringan bagus, tapi di pake buat ngirim tugas loading lama banget... Tolong diperbaiki lagi y',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.44',
#   'reviewId': 'gp:AOqpTOHAnhVZH3VZmpaa_4v162u9V2pwDC67rrICyFJLTNWpwRjLg6oOahBs2uIEoe6jwS7Tw_F4iJJ-dAZ5Ub8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwpgZ_1r-TLI_aZYCy7fRhZ_uItuL243Tk3uDZ_=mo',
#   'userName': 'hesti ana'},
#  {'at': datetime.datetime(2021, 8, 8, 4, 47, 44),
#   'content': 'Semakin membingungkan...!!!! Aplikasinya bikin kita menyebut berbagai nama binatang!!! Buat kepala pusing!! Udah updete kepikir untuk cepet2 eh mlh sdh updete kelas yang diikuti hilang semuaa! Ketika akan mau bergabung lagi, eh malah tulisan gak jelas! Seperti pengajar belum membagikan tugas lah, apa lah. Padahal sebelumnya baik2 saja sebelum updete, nyesel sumpah.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.05',
#   'reviewId': 'gp:AOqpTOEJIqpp8Usc9_uCA-R0p6sNg0PcGkL_EoqE8KBjS-QKZJZdkwnI2tkZWB0vft6uj5Pe7hHzRL0Skd7VJhI',
#   'score': 1,
#   'thumbsUpCount': 139,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjtEkQr5GXwuw3xLMF544OvGDc7tS8GmPFMczu3',
#   'userName': 'Meli Animaseo'},
#  {'at': datetime.datetime(2021, 9, 18, 10, 25, 33),
#   'content': 'Aplikasi ini sangat membantu saya📚',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOHtWu3ZHZCWRISYW5EOmRPU_0vTx3B85jhLTLaOdg1DuiVHobbWS7sGxvF1IMWLl64FlAGV4expdMZPtW8',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgjMdXe6T0fGijZZruRmcODiNyG5kEMN7iaZ2Vd',
#   'userName': 'Neza Naru'},
#  {'at': datetime.datetime(2021, 10, 12, 6, 16, 6),
#   'content': 'Cukup membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEUhiu8DTzvlRb_WuFzAmA83_vNGcQvWvLeIfdCuUdgpxTSh2icpdH-feVWDUqJWlejVFmLeLVfrmGeH4I',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzsr9GS2gZug2BjVOUScrVJWNIC40e4wwdeviaT=mo',
#   'userName': 'Rafif dwi Prasetyo'},
#  {'at': datetime.datetime(2021, 10, 11, 2, 48, 5),
#   'content': 'Gak Tau Kenapa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEPGWNeQCko6fK93KT7YL8Ll-zEoxvT5LWZjhi4akp5DXYb6DnZdAER6iIjELY4BrsoJARQ5xJAvCOd9Qc',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi5mGzkUK2hSSAIDpxMpGLEtduD9NJAWgbocrcl5g',
#   'userName': 'Farid Ramadhan'},
#  {'at': datetime.datetime(2021, 9, 30, 22, 42, 50),
#   'content': 'Tugas oh tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOEPD21WKWWCWJ8t1ABW3nQCqU66tTCdM8uoEayY22H_RcItTrzwKkbn3okdEL0VhqENpUqv0Tz62NhHoLQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjzq4SUqausRpHKhOejpN1Kvm4vJNUt3FKMz0Pc',
#   'userName': 'Tb Bintang'},
#  {'at': datetime.datetime(2021, 10, 28, 11, 24, 1),
#   'content': 'Mudah d mengerti',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFkS8wHBudnSbUv1KE5KxQNaHUcExRArqP-l2HOekiAmNitPKwC16FHkQCcw9R1t5oLMcW5rh_t9pNtK_Y',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjgVj2rQuQJLTyzKumQDEdL4rcAqOZM1dJwdM7a',
#   'userName': 'SATRIA Pratama 7I'},
#  {'at': datetime.datetime(2021, 9, 19, 6, 1, 1),
#   'content': 'Tau lah kenapa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOEANo05HxqTqxtsb-ZOgWnPVAG027nfzFuX27vR8dPy4L5TINnpuhpHqreO2ffOZbG8tXhkuyKJtmMO-zM',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiyDakyTZvOam6yoW-m_rxWM1pn_uAkIm2YyoXxrA',
#   'userName': '33.Salsabela Aprilia Aryana Putri'},
#  {'at': datetime.datetime(2021, 10, 14, 1, 49, 35),
#   'content': 'Buriq ajg setiap bangun notip tugas mulu Kon tolong di hapus bug nya ya ngen',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFj5Zd1HeAEKarDaxJ-7Al0qE6SPPNOosXC9hQGeoA1-1rB-8K1ORSyYizwWTFCFC0idC0JPCQEPZP735M',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz3dZVdpSIfzTKXN6StfrgzAejhKumyEEYC_Gao=mo',
#   'userName': 'Jojo Jonathan'},
#  {'at': datetime.datetime(2021, 7, 22, 11, 40, 18),
#   'content': 'Aplikasinya bagus. namun masih banyak bug nya seperti kadang muncul notifikasi tugas, padahal aplikasi tidak di pakai sama sekali namun banyak notifikasi tugas yang muncul dan membuat kesal. Mohon di benarkan bug nya agar tidak muncul notifikasi tugas lagi, saya kasih bintang dua dulu, kalo sudah tidak ada notifikasi tugas lagi saya berikan bintang lima.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.40',
#   'reviewId': 'gp:AOqpTOHOiOgBFvAo9bOPMeef8X-wS-BhM_AYrMN7lnZqp1ywebOmC7Btppqk2Z648YWJYhj-EOUd_NTCHouZgok',
#   'score': 2,
#   'thumbsUpCount': 11,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzLMJOFPmf8z2q3LQViXmBSVvcTPr0CeG2h7HhD=mo',
#   'userName': 'Terlalu Tampan'},
#  {'at': datetime.datetime(2021, 7, 24, 2, 15, 15),
#   'content': 'Aplikasi ini sangat bagus dan bisa membuat berkembang dalam suatu pelajaran dan dapat berkomunikasi dengan baik. Saya dengan senang hati sekaligus menghibur para pelajar , saya hanya ingin memastikan bahwa kalau apk sangat membantu dalam meningkatkan prestasi belajar .. Terimakasih kepada yang membuat kan apk ini . Untuk para siswa SEKALIAN sebaiknya kalian segera mendownload apk ini . Jangan Ragu ketika tidak ada yg menerimanya.. Semoga beruntung . ;) . Selamat belajar:)',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOE8Ap_QTJIEuyR9I0Z3iBlcliRZ2UZNKdIsZSJtzjdciiWKuLDCOENtyx2H_QFPYu-mGuwCi5QUMUnU0hg',
#   'score': 5,
#   'thumbsUpCount': 571,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzVj_yayzmpaaetskzvl4pTMVct-bhAKb9Xm97k=mo',
#   'userName': 'Widia Ratnasari'},
#  {'at': datetime.datetime(2021, 9, 29, 10, 38, 33),
#   'content': 'Cape gw di spam ama guru dri apk ini asw lah',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOHB3IFJ0nq2dyNJs3p0Hsg-SEhUN6dmlVHIVfYuQws9BWT6WmS_L8M4DxmOpHb75aQ7hm-u89JFT_q-9NQ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiSeH3JcRLxfDrX9aXjFdoeILonvsJgwN4XkC3hnw',
#   'userName': 'CROZZ GAMING'},
#  {'at': datetime.datetime(2021, 9, 9, 0, 40, 58),
#   'content': 'Kenapa selalu waktu saya sedang santai tiba tiba muncul notifikasi tugas. Semoga cepat di perbaiki bug ini agar guru saya tidak mengirimkan tugas lagi',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOHSen0phqlMDt2dYPep03KhDK93maFJUF6K1R-u1-2M0OuO8wcngBibNYFoubRGeepkvqlATrJYaAMITGU',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggb8_-dQ8X8DHb0qRoL-MfUl71R3Wp4scD07LYftw',
#   'userName': 'Gio Tabesi'},
#  {'at': datetime.datetime(2021, 10, 11, 14, 47, 38),
#   'content': 'Guru Stress ngasih Tugas ga ngotack bunyi notif mulu aowkwkkwk',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOH4BNoNswU0YDxBptbonpHBuUh21Q6KXAGH_NshxWhAWbbeX9GCLq2FJKZA-sY08V2T3TQmT4EEjeU4Tnk',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxC-HME9b-RkPa43UTL0-IweiU0XRfa2PlInRxq=mo',
#   'userName': 'Wennn Official'},
#  {'at': datetime.datetime(2021, 10, 18, 5, 33, 56),
#   'content': 'Bagus bgt gcrnnya sya jadi sukaaaa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEh6c0t3jT1op5T21oudsLhlkR9mqGMP6myr0saHki7LxHqJb4AxsOyfDwrLyL-6NUIm9udIiczQ5DjpTA',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjI7HheadrsRZK5IUGB5d1GuIkkL7bGRRLIfgLf',
#   'userName': 'Indah Minarni'},
#  {'at': datetime.datetime(2021, 9, 5, 3, 54, 50),
#   'content': 'Terimakasih banyak atas aplikasi nya, ini sangat membantu pembelajaran saya terlebih lagi saat ini pembelajaran daring,, Terimakasih sekali lagi 😊🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.33.03',
#   'reviewId': 'gp:AOqpTOHOs7iHqs7wMn6r61U0PF6HaaPtHLbsGnWrhD7tr9LVzzlBqe-Vql-UFWUsMteM7yQuh5xjRyMe6_G9ik4',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgWpQGpu0tn51TIxkrn7-3QTGHcjIvMOKc3yt95',
#   'userName': 'Tsania Qurrotul Ainy'},
#  {'at': datetime.datetime(2021, 10, 1, 1, 36, 5),
#   'content': 'tll banyak tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.06',
#   'reviewId': 'gp:AOqpTOHitXYINZqMArTkEE16mKaMPSkBWEe6aACQXuJ59ovK9vpMvtwU0Ea9XdkEE5wqZO4ISliBQmEFr8PVa7Q',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjXIJLaJl7gGi2AHeb4PUvIBKfUWNIxr4C0NdaSkw',
#   'userName': 'Rizky Ramadhan'},
#  {'at': datetime.datetime(2021, 8, 13, 13, 35, 10),
#   'content': 'Assalamualaikum...perkenalkan saya Aghnia saya menggunakan apk ini untuk belajar kls 7 (SMP) apknya sangat bagus!!!dan membantu saya lebih mudah untuk belajar online di masa pandemi saat ini...terimakasih...sukses selalu untuk GOOGLE KELAS...🙏🙏🙏💐💐💐',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.30.03',
#   'reviewId': 'gp:AOqpTOGHuJw8SfwAp3SV-HKk-HEaFCD9tUcCdIZbUkILPcN0yJclya88yWXwot0r-JIDjRXRHvUSlEdixOECKYY',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiBfMGOOla6SdNbJncSvER0WCjD0xI2uGFb2Ag',
#   'userName': 'Aghnia'},
#  {'at': datetime.datetime(2021, 11, 28, 0, 37, 58),
#   'content': 'Nambah pikiran',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHYXZ_L8LbCKDdhMkPtYBXOqM_JiHUk2tLZ4hItF7J_mPBJsodNS_xFQaxEuxbcaPArf1VTnk2SCxJ5r1w',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgflN8YJcgCFP_wTI52IXZwhC7AsRGM8lrYF1kdzg',
#   'userName': 'zildan raihan'},
#  {'at': datetime.datetime(2021, 10, 28, 14, 11, 7),
#   'content': 'Aplikasi keramat',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOGAUWAlklCPSEKb5cmpp7iYmzlSUQ2yNejwP4B06wwx6BlQ4UGuDrjNUrMbaIgd7FLNVB8pFEuEdQxZoEg',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GitiETY5yLJ5ZXg9pifgKMHgf7L5ToOd7w18NyHoA',
#   'userName': 'Unggul Adhiprasetyo'},
#  {'at': datetime.datetime(2021, 11, 18, 15, 23, 28),
#   'content': 'Apknya bagus Bisa liat brainly ehe',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFRpzSbBRkg9BHoc8llruUDBbNCQKNCFAe0HDxU5f_6Sxw0dhyNWKZt4-6L0FKAF4FXaEd4SZ7c6M6HsLM',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi_z-bdG5vFUL55cCovrwnWcnOittL7sO6_-k7onQ',
#   'userName': 'Kiana Gunawan'},
#  {'at': datetime.datetime(2021, 7, 28, 1, 28, 17),
#   'content': 'Terimakasih sudah menyediakan aplikasi ini untuk kami belajar. Tolong di tanggapi ya GC. Untuk saat membuka pelajaran yang ada, tolong di beri nama guru / akun yang memberi tugas tersebut. Semisal Ada tugas Matematika yang di kirim ke kelas, saat di muncul tugas tidak ada nama yang mengirim. dan ini membuat bingung siapa gurunya😅. Makanya saya kasih bintang 4 dulu. Terima kasih',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.40',
#   'reviewId': 'gp:AOqpTOG9deaM8JTjRLyEl_RpSoeTxS2iH_ofphUQMhJl6wAEw5C-k3d-Dbcflims3OEGgP2mzL_eqDxgQQwweok',
#   'score': 4,
#   'thumbsUpCount': 3,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiDIjJoR-0aBLBrHKIchhXBRpIskh8KFV0EfvWzOx4',
#   'userName': 'Fadlih Muhammad Ihsan 02'},
#  {'at': datetime.datetime(2021, 9, 13, 3, 54, 9),
#   'content': 'apk nya bagus tapi sering ngebuk,buk nya benar benar sangat meresahkan dan sangat menganggu,pas lagi enak enak nya pus rank malah ada notif tugas tolong segara di benarkan terimkasih',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOFIj6WrYheiJMHj1gKPMNPbSg1zKwWOy537vs8ik3N5tXK5Wfe_a3cqLWMG7GZ4NPN-KworWwWdZFbW_WY',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwSQn5U7K62CsBJ3mVy2J4BSYfLpQj9zsgrULf7=mo',
#   'userName': 'dafa Dzaky'},
#  {'at': datetime.datetime(2021, 11, 9, 14, 23, 26),
#   'content': 'Benci Ama Tugas 😤💔 Awokwokwowok 🗿🤙🏻',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.421.20.90.1',
#   'reviewId': 'gp:AOqpTOHG6w3W4C_OUXtMzoySBQEGPnXseRIoptODc-1RVO4IDjp1WCR7-LW8R5SfCnWNdffsoEu3wu8ImHB90NU',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgY-bwxCrL_2fRsaun-CSCGFBQUBbq1tSyVwvrqxQ',
#   'userName': 'Rayhana Noor Zalma'},
#  {'at': datetime.datetime(2021, 9, 20, 3, 29, 55),
#   'content': 'Goblok... Gabisa ngirim tugas asu babi anjing',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.45.04',
#   'reviewId': 'gp:AOqpTOFvfYbmRw7sLotsuhNnrO_Xe1_AqVfkThhvdw3FemlbKZKorZ8Ie_2pw2lFee4ZZYOLqRsni7YmEuLFI_o',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgW6S4lV_X34rAH-Ybcc6MqP-Smdd0KlSXmigXQBw',
#   'userName': 'Abdillah Nabihan Tajusa'},
#  {'at': datetime.datetime(2021, 7, 27, 2, 52, 45),
#   'content': 'Gara gara nih apk jadwal nonton anime jadi berkurang 😠😠😠😠😠!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.44',
#   'reviewId': 'gp:AOqpTOFmykSQ_XP4XdKHeMy6PobbtDTkYiTdx-qk8TpGtR_TElnY7vAeXcy45rw6srzt4BjROjgHD9MjTJAelOk',
#   'score': 1,
#   'thumbsUpCount': 30,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghf-5N-bU5DfkZPnO1El_8i2qSvaw__ienNMh2ajg',
#   'userName': 'Veryan Kurnia maryadi'},
#  {'at': datetime.datetime(2021, 7, 21, 3, 4, 1),
#   'content': 'Bagus membantu tugas turun ke kita,tapi knp banyak yg komen "aplikasi ini baguss!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!apk bikin tugas numpuk"yg ninggalin tugas siapa?elu kan!knp marah"sama apk nya aneh lu🗿',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.04.40',
#   'reviewId': 'gp:AOqpTOHBV-d4eB_NfEhdLspbGKm5P9Y5wrhtBbhmJNtpB_KNJ4I0RaN8mK-v7eJ10Erit28OVqMIVCyjUFJ7Ees',
#   'score': 5,
#   'thumbsUpCount': 433,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggc1UjN4BBxTM297IXgqRW_DLvt-xSS3pys2EiH',
#   'userName': 'Hampa Dari cahaya'},
#  {'at': datetime.datetime(2021, 9, 25, 4, 48, 59),
#   'content': 'Gegara lu gw jadi pusing',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGBHGjdqJ_bAeV3FghhiWwb7RTLVBRVz49TGnU3DL9B5Ds5fAtLStmHQzRyhmomphQTrxPzmn3URke_OEg',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgnjiEsqFALZYTjRvxdsPQHahevplF1ZNzsIEkudA',
#   'userName': 'Muhamad Anshori'},
#  {'at': datetime.datetime(2021, 9, 16, 3, 14, 49),
#   'content': 'Terimakasih sudah mau bemberi tauku soal tugas 😇🏘️📩😀😍😀',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOEP1QZMbHq0ULATpw34hHpFONhLRmS59z4kjjB1LhRFA8PHoAM-T78HIOQV9aZdi2CBrxtItG_dolylURk',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyUv_XHne7xeyJso7r5Z9QRkVfKTw508bbJx18t=mo',
#   'userName': 'Ajeng Ayu'},
#  {'at': datetime.datetime(2021, 9, 4, 5, 17, 19),
#   'content': "Saya mau mengirim tugas,mengapa Classroom tulisan ny 'anda tidak dapat mengirim tugas' tolong di perbaiki lagi yh!!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.40.07',
#   'reviewId': 'gp:AOqpTOFfAHPCF5XX7IOTzElmOUt134oI9AhY6SJxKZiHrZ-OMBCVuIyfiikWeju_j939BYz5-aMAWOOW-c9b-rA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhYafkixN2qKQZSaSTz2PYhBWSQkc4r2kL30C_c2g',
#   'userName': 'Hana Natalia Pembriani'},
#  {'at': datetime.datetime(2021, 7, 26, 4, 20, 38),
#   'content': 'Apk ny bagus tapi apk ini membuat tugas saya menumpuk!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Aku pusing tugas banyak',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.03',
#   'reviewId': 'gp:AOqpTOGcwp5hJp4ICcQd8iRGW1ejRSDUQvBrdNsCzqGFmu_7g6YBYvbGQTM7OAuK4MSkJXuylYWH_8tslzbMKgY',
#   'score': 5,
#   'thumbsUpCount': 327,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg0d4BPP7n7Ec-XzsX46hstZ97vZ3odQ3GU2DLQ',
#   'userName': 'Rini Sahrini'},
#  {'at': datetime.datetime(2021, 7, 26, 8, 13, 5),
#   'content': 'Aplikasi ini bagus bangett!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!Tapi boong hahay pale pale jing',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOF9MOQKzh_1nytmruHnaD5HNf8TbTrMPkokpixQ3E3RoznDSxK_UE3zA-d9LhG6n0iv6w1i2jJ-2nmOgqU',
#   'score': 1,
#   'thumbsUpCount': 470,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gj9a6z0Q6z3NOn7md-dFAmKEibvB4ELqJlO0LWt',
#   'userName': 'Cokorda Bagus Hari Sedana'},
#  {'at': datetime.datetime(2021, 10, 11, 9, 3, 8),
#   'content': 'Guru suka spam tugas🗿',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOFb6EYegGPGfMbJ2omlNXfiQwT3QyewgANFSF2c6Xx5kZcR1J20wH6IF72bT-p1f9gEelBNXcP7cLScPI4',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gjtfn4dqTF0c6M8XKuYfePWCZz9Rkw9FmBqqCxY',
#   'userName': 'Aryo Bambang'},
#  {'at': datetime.datetime(2021, 10, 15, 10, 7, 12),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOH-7V33gwEiM4RlTCApr7ExjjNBRPZRcmrOJCuy4D3Z6UGOAUI4fqqfzL7Pf6WTn1RbYV6OWpUQrd_FsrE',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi0WMqCe9D-gVUuuixr1OiBiqO8m-y5sYrQS08RxQ',
#   'userName': 'wahdah kusnadi'},
#  {'at': datetime.datetime(2021, 10, 15, 0, 33, 28),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEur2zTYv5nU-qQDdaPj1Np32ewDbQPmG_RYeMeMfDRNbId1UBnjP_83kGq8JZTQC--JYWyifP4Gb7nySU',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJxjFRT01P-TYGEKWvKiuBbGot0nSIXyQ_h8voYX=mo',
#   'userName': 'Ria Komariah'},
#  {'at': datetime.datetime(2021, 10, 13, 11, 46, 9),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOEpDFJKcK98CvJIdq0r-9lWUiA1btaDQsAJeIGXkTO6LCSWpNu4T60AvfD08WuYbvL8rUJO0eWz0Y8la9o',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJx0PdxHh2H3L91oDQDh0pX0FtgjOya3Ep2XTWDr=mo',
#   'userName': 'Aten Aten'},
#  {'at': datetime.datetime(2021, 10, 13, 2, 12, 35),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHhbut7ACnCxXM4BjnXmIcS3qeXMxGoj6_OrEo0hkyFjsY25EP5LyjX7S47D0xFpAdAZRF6_5t1VMjEcUQ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJz5BZLsw0gV-oUhLfo9I2WVCw2qlUJ1Nee4j6r8=mo',
#   'userName': 'Susi Nurulhidayah'},
#  {'at': datetime.datetime(2021, 10, 11, 1, 20, 16),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOGhNW0CbWX27v9vUoHI1Y4O_OfQDlSvDHQyq84S7UNQ-ZoTqp2IjLKByX0VOVCHmdBfygLsxYxuwVMW7NM',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gg4QsudMjbUqE3VlpSideqMWDo7lrCHTvhFqBCY',
#   'userName': 'Bintang Eka'},
#  {'at': datetime.datetime(2021, 9, 9, 18, 41, 43),
#   'content': 'Kenapa stak di 99% pake wifi sinyal bagus, pake kuota masih banyak tapi kenapa gk nyampe 100%,kenapa ini?????',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.34.07',
#   'reviewId': 'gp:AOqpTOG2GpkgrCKCXb9p_LMbJCY0hgDHw_3LbbxGrkWWBjN-n3zG_5RAqN_1TnKgJdvboTV76PD0nDAXOAc6JWs',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw6-V3ukW46-f_NAQNKOYw6PvR8nXgQi3uyP9Bw=mo',
#   'userName': 'Viona Nayla'},
#  {'at': datetime.datetime(2021, 7, 23, 23, 17, 14),
#   'content': 'Tugasnny keren bet!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!keren bikin orng pusing😌💔',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.40.03',
#   'reviewId': 'gp:AOqpTOFLha54IiSaXNbnPpT816Cu5aF2VRo2Zz26RI7S3AmP3lhIoVhtV48uwIibMOyvzKy9xeNest0Rq2siL3o',
#   'score': 2,
#   'thumbsUpCount': 280,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjaRrQmLIhBnnzuLYCMnCDI3jj-8JlIxk0fmxiR',
#   'userName': 'ff •astro'},
#  {'at': datetime.datetime(2021, 9, 16, 6, 4, 49),
#   'content': 'Sangat membantu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.34.04',
#   'reviewId': 'gp:AOqpTOE9oC4vsBQ3WxxicQ6AoFtw3fKC0SUI3dtH97Cz08iY6jyvAobJgbgEyfF5Qv0pKRab1xFhGSIR_xSnlG4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggo5ne9pz_fum-FP03MHXdo5sOx3eCAh5HzRKICgA',
#   'userName': 'Brian Ricard Wola'},
#  {'at': datetime.datetime(2021, 10, 5, 8, 41, 59),
#   'content': 'Karna suka error',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.381.20.90.2',
#   'reviewId': 'gp:AOqpTOHMAd1hSJco0IoSexxzcwR_cBSbjfiTQhRs04gs9lziS9X2rsvWMc-r9YOSavfJQmZmSYjRmgMDkHyZi9s',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghgj8LpI6hibAZcSRL991GTJ838sCk3UYIw5rTZ',
#   'userName': 'Abu Ghaniy'},
# ...
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOGK_tEfOmv_Gg0GRXncZ7OKOm0YTdAO0NjvxHLJdiMd0U1wMHDzaMnU6GkwwoCWvE0lJAYgbLR7uQNxJ68',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgYlGrW5mak94GzebxWJmc7EajKEPFiiZyJPl3S',
#   'userName': 'yoraa jane'},
#  {'at': datetime.datetime(2021, 9, 13, 21, 46, 38),
#   'content': 'Aplikasinya bagus lumayan , Tapi kok ada bug yang tiba tiba ada notife tugas yak ? Tolong di fix soalnya nganggu bgt ajg🙏',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.44',
#   'reviewId': 'gp:AOqpTOHmrxPj64QXqidvvNvv8hPT6UVmt4phHHSzcx2CzYFhHl83KNWC7Gu89s7q_I1_cgR7HRPXsjyO4gPO5x8',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjJ4FFc8cDNICqsnQlteJtIhFc5sTHOFWr9hE4p',
#   'userName': 'M.Luthfi Mishbahkhus s.'},
#  {'at': datetime.datetime(2021, 7, 26, 12, 19, 17),
#   'content': 'Saya rasa aplikasi ini sudah bagus dan baik. Tapi saya sarankan ada tambahan fitur pin, agar lebih mudah menyimpan tugas atau pegumuman yang dibuat oleh guru.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOF-dGJS2zjV97noYLBPWl1cdxB5x3rKYlnJZKiNFTLxDOP4BxIHjSRIRt6O9_JC3CTUxPbD3ZqUKqex5ys',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwKlwA08j4m6KlAdiYKNK-Bi7GzCNEb683zirjV=mo',
#   'userName': 'Ghozali Refin'},
#  {'at': datetime.datetime(2021, 9, 19, 13, 1, 40),
#   'content': 'Bagus aplikasi nya tapi sekarang udah mulai new normal jadi mungkin bakalan jarang di pake',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOHnnpcp-C-5K_WsPS3TLb1dR-L-1iZMZVaQiEPk3ZO7OWxoTtkpKSq2oZJO6VU0XSCkzBZtBPhCoIagDEM',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhJSWX0o07uLI_YnpebUqOZw8qi7a0EToRhYZJjLA',
#   'userName': 'Dila Istiqomah 9B'},
#  {'at': datetime.datetime(2021, 7, 25, 5, 11, 37),
#   'content': 'Ga usah donlot apk ini gw saranin kalo ga mau kepala kalian pusing gara² tugas numpuk tp yang mau cari penyakit silahkan donlot aja sih ❗apk ini hanya untuk orang² pintar kalo❗',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.40',
#   'reviewId': 'gp:AOqpTOG-UITPqnr6-8QiMn0-AsD-5a-tS3cE8xjdc-MYn_Tcalq00Ml5zkXeQjQeeiOp3a1JJX9yojDw6UHJJsE',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjnFlf7Aw9fl_XkL1yrjqJ3vT06-yhFcrC-YEgN2w',
#   'userName': 'ʜᴀяɪs ᴋᴏᴘʟᴀᴋツ'},
#  {'at': datetime.datetime(2021, 9, 8, 3, 54, 11),
#   'content': 'Aplikasinya bagus tapi kenapa kalau setiap mau uplod perekam suara tidak bisa ya tolong dibetulkan',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.33.07',
#   'reviewId': 'gp:AOqpTOE1OcN-yevZtMLmKhZv270bbOZZmaB55OUD10DXxkO_fPBcZbJptZbcufj0Q20y57iwBihlgzHjXPpnjxg',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwaqAv40OeSDIpGlsQpniPXZvcO_WJK1bhWomIS=mo',
#   'userName': 'asraf liandra'},
#  {'at': datetime.datetime(2021, 7, 27, 2, 58, 19),
#   'content': 'Apk gk guna!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.40.03',
#   'reviewId': 'gp:AOqpTOGqOo_9SnjvQ5KydvCrwnHpabvYgp6M-Oipx6goX4geJ0gmB91e5fEK_LvJZkXkk5E9BNHTaGeqPWmqWJQ',
#   'score': 1,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiWvyoUBRE4SW91WOeWCqonHBeqtJnDwp92td1u',
#   'userName': 'Azril azril ? Alif kurniawan'},
#  {'at': datetime.datetime(2021, 9, 1, 4, 6, 20),
#   'content': '1. Kadang notifikasi tak muncul. Padahal setelan notif untuk aplikasi ini udah disetel, masih aja gak muncul.. GILa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOHIKAeC4Y8PcIW9CCZ36_YO1bvyxcP2KLIeB-gocqtkHYu5zdUfkPTRy978EFnk2VsRYakoetyQ1NycFps',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi9CrvVSX8sBRTO42CwvIASi8nEzMS7wXisCsi5hQ',
#   'userName': 'Melvern 19'},
#  {'at': datetime.datetime(2021, 9, 22, 12, 50, 31),
#   'content': 'Error kayaknya nih aplikasi, kuota masih banyak; buat ngirim tugas aja nggak bisa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.44',
#   'reviewId': 'gp:AOqpTOH6YEfzODljJ8oc1gytZdTY18vP_O5nsUaFvWFr0BIDTNzY8rV-QdtHlYuXNRUXprYD7rhGEQaOq8v92fA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwR9SHxPPro6Zoiz8N1-0GmtgsbQxbvTQN4ffUQ=mo',
#   'userName': 'Kahlil Krisna'},
#  {'at': datetime.datetime(2021, 8, 1, 2, 50, 52),
#   'content': 'Bagussssss bangetttttttttttttttttttttttttttt!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Ngapain liat liat kebawah kan aku Uda bilang ini bagus😒',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOEsSYypQ_INAnr_03y7Jee60IEAJ5e-p70axFZVYksZKc2xE0-wSCxdZg09k3cAYWiChl500yn4-wVrD0A',
#   'score': 5,
#   'thumbsUpCount': 194,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhFUs_aJHzZTMMlF4CbZz2n_7ZCW4F0hYeWy5IF',
#   'userName': 'Lysa Anggraini'},
#  {'at': datetime.datetime(2021, 7, 28, 23, 50, 47),
#   'content': 'Banyak bug,pagi pagi selalu ada notif,kalo gak dicek notif nya kita juga yg gak naik kelas,bug macam apa itu ya....',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOFjvGmD8PLjEP89Dxz5PJfv7A6DKviH3KEZmrZBcb8VBb2gDTpG9S5i-UZ-myDEuRhtqQ_vzkthC-Ls4X0',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ggr9pOYAIX_a_17Uth5qTuXXKK6IbhZPm7HywkSrA',
#   'userName': 'Diki Ramadan'},
#  {'at': datetime.datetime(2021, 7, 27, 5, 24, 58),
#   'content': 'Apk ini tidak cocok untuk anak di bawah umur banyak bug blum di perbaiki bug notif yg lgi tiduran tiba²ada dan tugas yg banyak sekali tolong perbaiki bug ini',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOHKKKjHwaU9Tp-o8ExyNPqdlrO7A5bv-wBXAf_BlFZgy4sC6Cvc8S6Id-Mrflme5SQmkngSqh_a9mypSW8',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Ghc3HbpykCv-LFlvm01DcfWjJAxLqrCuuUEGkeuTA',
#   'userName': 'DAFFA 8C'},
#  {'at': datetime.datetime(2021, 7, 30, 6, 12, 34),
#   'content': 'Apk nya bagus sumpah gak bohong,dan yang komentar lambat dikirim tugas nya terus apk nya dihapus aja itu mungkin gara gara internet kalian itu yang disalahkan malah apk kasian developer nya aku ngirim tugas ok² aja.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.33.03',
#   'reviewId': 'gp:AOqpTOFY3LeQHTfC3EjHoUK2rtE55qI1jtX9yYmQWLL65KybPs-gx9QulQxs0TfogsIe4mh0893maUnFjoWWdQ4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhHZ9n9w2QNbpnuJHgIKpQng36i_tXoi1vwXdRH',
#   'userName': 'Mutiara Sparkly'},
#  {'at': datetime.datetime(2021, 11, 21, 13, 15, 5),
#   'content': 'Aplikasinya banyak bug, masa baru bangun tidur tiba² ada tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOHcTVR4JlyR0A-Zn906Ny7tNZbJTwfcO2TuExqV0pP_ewA9H6Wtn8Qqy7CvTYn-U1OxX1aKZqqODL59Zxg',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJw6-NUnNs_8j-LFSh-ES3R3udx1S5xK2LkSLUSk=mo',
#   'userName': 'Bagas Pranata'},
#  {'at': datetime.datetime(2021, 9, 13, 15, 24),
#   'content': 'Kontoll yang buat',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.40.04',
#   'reviewId': 'gp:AOqpTOGqY6LMsJmjuzuyIcEsbpmL0B5skk8UD8Lp_jtMctndr4yyMoz99syIAB4cNBM7nZlmmNCRz2agsH7VE6o',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhZjX2JkAyguWPg3BKqqAlvSyL6t4fq2Vpy3-7_Fw',
#   'userName': 'Gerard Adhilaksana'},
#  {'at': datetime.datetime(2021, 8, 2, 7, 46, 6),
#   'content': 'Tolong baikin bug ini,di saat saya main game selalu saja apk ini mengganggu saya bisa di bilang notif spam buat main game tolong baikin bug ini secepatnya!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOF_eIWxLWyepDuFh5kcREx0qiDG-9Jbr5Z3jCvv4YpV3T7RDY57GDjLeBSQQCQLujdtEzaZ30dRScvTiSs',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhtJJ2U3vizp8e85IATxH_3yILAOrkiNshDmp55',
#   'userName': 'HanzzZ'},
#  {'at': datetime.datetime(2021, 7, 27, 2, 17, 3),
#   'content': 'Mantap kali lah aplikasinya tapi ada yang kurang admin tolong di benerin sedikit biar ada notif masuk biar tugas saya ga numpuk maaf kalo ada kata yg salah makasih min',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.34.03',
#   'reviewId': 'gp:AOqpTOErRy28vBiGYXdDNjeXDm4qN7wsSeXcXMl-yQ-PXWFJAsIQlMZRYjtzyqrheaKPwWKitLfgL_EIqYbywrE',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiOmQilq51Z5iHlB0kwl2D5zzpu0QWxkoksdNiryA',
#   'userName': 'Ff Bobs'},
#  {'at': datetime.datetime(2021, 8, 5, 4, 10, 23),
#   'content': 'Awalnya si bagus,CUMA setelah update sy tdk dpt notifikasi sama sekali.padahal sudah dikirim,jadinya saya terlambat mengerjakan.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOHBYgWzpbS8uYZGM_Rnj1JxFaH1cp9XBTWa8b_gtSJEeiQYEnf2UbCl6cxAFTbVmE7JVY97n7FjNKxJOGo',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GjjYeMw-A6MHMNmeI4KgWkqvnRSb7UxaWx86igFZA',
#   'userName': '30 NI LUH PUTU LENY ANDRIANI'},
#  {'at': datetime.datetime(2021, 8, 3, 4, 3, 9),
#   'content': 'Lebih bagus kalau gurunya dapat memberi label no absen pada siswanya. Terima kasih, sangat membantu skali aplikasinya.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOEDhVKMnyo5E4NFOCohIkyLTXOtDtB-lHOKqR6PCKy5kiO2ayCGq2WQ9svvl87cNYitsp8-zMot4KQ40Es',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GhpvfMyN3ca85_Z-jhUKY-DouHxaOaB_KgM8Y-Wqw',
#   'userName': 'Ahmad Azizi'},
#  {'at': datetime.datetime(2021, 8, 25, 14, 46, 26),
#   'content': 'Gila kenapa error terus sih?!udah diupdate padahal tapi setiap mau buka tulisannya "maaf tidak bisa .coba lagi"',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.45',
#   'reviewId': 'gp:AOqpTOE3rVuRhIduHcAraUOjOkl4xlRTwAE2-kpvr5WAxLy0GgVGVAs0h7w08b4bGoAFPP-io0y4yUX8z8Gr6UA',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GgMxZZaIHsnjFxzaqE6GsCJamLl_R2t5aenZPAQ',
#   'userName': 'nara juniar'},
#  {'at': datetime.datetime(2021, 8, 12, 18, 31),
#   'content': 'Harusnya membantu... Tp malah bikin sulit... Kirim tugas tidak bisa2. Sudah diupdate msh tidak bisa. Dicoba di lain waktu juga tidak bisa',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOFxoRcp_HrgH6gtY6gZN97wqSowS76oVYugA7ysE1BvGJ0yZliGhnoIipGy8TRfl-SayQ8v1-MBSTzd-ko',
#   'score': 1,
#   'thumbsUpCount': 15,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiV7NUICihqAt2Xq28rZVzG3RPCLhvtr2vMklJScw',
#   'userName': 'Indah Carollyne'},
#  {'at': datetime.datetime(2021, 8, 26, 11, 16, 13),
#   'content': 'Gue suport dengan apk google kelas/class room memberi dampak bagi para pengguna terutama kaum pelajar yang sangat membantu apalagi dimasa Pandemi.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.301.21.44.07',
#   'reviewId': 'gp:AOqpTOFbS79oHSV9Eh4Jik3diVslQJ6UXHAA0DQifDdcYudqbxGWPasi6g7cI7PN_cji9ILkiuGaGUbFvDNm_xY',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiN9FJKOkyuCx2pbI0D5H07ctQJc3gmWPGR7WC4eA',
#   'userName': 'Stenly Wetik'},
#  {'at': datetime.datetime(2021, 10, 18, 1, 32, 4),
#   'content': 'Notifnya ganggu',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.341.21.44.04',
#   'reviewId': 'gp:AOqpTOGAZ_D7733oJdrNvT-MT9scGvePBWGhSJNzgsfn7OfXF9ycMIi9MI67F2_XDvVAz24Lta_lP-wLUvvrvbE',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiJUCPysHHv3LjVOrdj95lphvJAgfLnir0gxi0MkQ',
#   'userName': 'Dita Aprilia'},
#  {'at': datetime.datetime(2021, 7, 17, 0, 31, 56),
#   'content': 'Aplikasi apa ini tiap hari di spam tugas plis lah kasih fitur yang bisa buat tidak spam tugas karena kami siswa tidak mengerti apa materinya tolong ibuk bapak guru beri tugas yang sewajarnya saja kami tidak paham materinya...',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.34',
#   'reviewId': 'gp:AOqpTOE2zxG578lcEfXRcTifCzuHUtXReEfeP6lCRFiL3uljnmYZsipSyL66lr4dL_7mS4WPfau1WpmadHwdadE',
#   'score': 1,
#   'thumbsUpCount': 4,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJwgujN6gzYx71ESKJmIz7ewcAkfENTDS_uG1SXF=mo',
#   'userName': 'Kura Ninja'},
#  {'at': datetime.datetime(2021, 7, 28, 4, 12, 14),
#   'content': 'Apaan itu ada bug tugas tugas yang sudah selesai kok malah ada lagi pas sinyal jelek harus di buka satu satu lagi biar hilang, di perbaiki itu woy !!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.44.03',
#   'reviewId': 'gp:AOqpTOERkLk2NllpfvJHjeLDIqdGVJOerLb1Nwu7U-YqrIH1lQPJfJE83aGrVwuFeGtHxIf2GMdOzVw1A5Z3Uw4',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GilhxPAdIVm1JPIQenIEIxFr9TMV4UPKkAVqLGbiA',
#   'userName': 'Muhaamad Rizki Fadilah'},
#  {'at': datetime.datetime(2021, 6, 16, 1, 12, 51),
#   'content': 'Banyak bug!! Lagi enak enak tiduran ada notif tugas. Bug ini sangat menganggu. Tolong segera di perbaiki . Agar guru saya berhenti memberikan tugas',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.03.45',
#   'reviewId': 'gp:AOqpTOEazabdqFuqVlkGja83o7r9oquYVv24RlmMNhElIXEIQJvs3zmoXrDGLFja52os3qtwVc7dxoIZgsCYDws',
#   'score': 1,
#   'thumbsUpCount': 431,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14GiL9lW_kfX_EJ7JJfydlLwx_ffZ2Cscpv5Ah4RadQ',
#   'userName': 'fangki arjuna'},
#  {'at': datetime.datetime(2021, 10, 8, 23, 46, 18),
#   'content': 'Aplikasi yang membantu belajar siswa secara daring😃 Hiks, aku sedih gara-gara pandemi. Jadinya gabisa sekolah tatap muka & ketemu temen baru:(',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.5.221.04.40',
#   'reviewId': 'gp:AOqpTOEVUXSpGFqT70YwF5VHbSQROQAZjucfgb5JGCdnyY8j8X3JKfi9LC783lZbGYwOjBawnvMlWy71Bu38kso',
#   'score': 5,
#   'thumbsUpCount': 340,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AOh14Gi6L6kZZyvMv06qztVke_QGf6VEvx5bqTTa0-DJWQ',
#   'userName': 'ROFI ARIF ROBBANI VIII.A.25'},
#  {'at': datetime.datetime(2021, 8, 6, 6, 34, 25),
#   'content': 'Kenapa bahasa nya gak bisa di ganti ke Indonesian padahal di pengaturan udah bahasa Indonesia di pengaturan hp juga udah bahasa Indonesia Tolong di perbaiki !!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '7.6.261.21.45.03',
#   'reviewId': 'gp:AOqpTOGuLLuLOJvSin4MQfLY0xgniojI2TepndhzvKyYm1dmhbKJfmr4MH_o_oMoceLFMtckkBbXe2FuNRHSp34',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJygiokDMpoxyBzUuOyYkbnhKRlXwUTbPl2-L3dP=mo',
#   'userName': 'ridho Yudhaaldama'},
#  ...]

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)

# %%
df.to_excel('Dataset.xlsx', sheet_name = 'New_sheet')
